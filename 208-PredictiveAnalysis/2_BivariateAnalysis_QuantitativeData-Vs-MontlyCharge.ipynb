# %% [markdown]
# <a href="https://colab.research.google.com/github/dayanaviana/WGU/blob/main/207-DataExploration_Project/CHURN_1_BivariateAnalisys_QuantitativeData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bivariate Analysis for Quantitative Variables

# %% [markdown]
# # Descriptive Statistics
# Describe and summarize data

# %%
import pandas as pd
import matplotlib.pyplot as plt 

# import into data frame

#churn_D208-1.csv
filePath = "https://raw.githubusercontent.com/dayanaviana/WGU/main/datasources/churn_D208-1.csv"

df = pd.read_csv(filePath, index_col=0)

# %%
columns_array = ["Income", "Tenure", "Outage_sec_perweek", 
                 "Bandwidth_GB_Year", "Population", "Children", "Age",
                 "Yearly_equip_failure", "Email", "Contacts" ]

for column_name in columns_array:
    columns = ["MonthlyCharge",  
           column_name]
           
    # Data frame with selected columns
    sample = df.loc[:, columns]

    # Check correlation
    x = sample['MonthlyCharge']
    y = sample[column_name]
    corr = x.corr(y)
    print(" MonthlyCharge & "+column_name+" Correlation = %.3f" %(corr))

    # Scatterplot
    plt.plot(x, y, ',', color = 'lightseagreen')
    plt.xlabel(x.name)
    plt.ylabel(y.name)
    plt.show()
# Out:
#  MonthlyCharge & Income Correlation = -0.003
#  MonthlyCharge & Tenure Correlation = -0.003
#  MonthlyCharge & Outage_sec_perweek Correlation = 0.020
#  MonthlyCharge & Bandwidth_GB_Year Correlation = 0.060
#  MonthlyCharge & Population Correlation = -0.005
#  MonthlyCharge & Children Correlation = -0.010
#  MonthlyCharge & Age Correlation = 0.011
#  MonthlyCharge & Yearly_equip_failure Correlation = -0.007
#  MonthlyCharge & Email Correlation = 0.002
#  MonthlyCharge & Contacts Correlation = 0.004
