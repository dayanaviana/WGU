# %%
#  Git link: https://github.com/dayanaviana/WGU/tree/main/D209-Task2

# %%
from platform import python_version
("Pyhton version:", python_version())
# Out:
# ('Pyhton version:', '3.13.2')

# %% [markdown]
# ## Imports

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from PyUtils import MyPyUtils as utils
from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeRegressor # Import Decision Tree 
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation eg:confusion_matrix, classification_report, roc_auc_score, mean_squared_error

# %%
filePath = "churn_0_Raw.csv"
df = pd.read_csv(filePath, index_col=False)
utils.writeDFToFile(df, "df_info_0_Raw.txt")
print("DF Shape (Rows,Columns)=", df.shape)
# Out:
# Complete details in df_info_0_Raw.txt file
# DF Shape (Rows,Columns)= (10000, 50)

# %% [markdown]
# # Remove features
# High-dimensional data can lead to performance issues and reduce the effectiveness of distance measures (curse of dimensionality).

# %%
# Remove data that is too granular
df = df.drop(columns=['CaseOrder','Customer_id', 'Interaction', 'UID', 'City', 'State', 
       'County', 'Zip', 'Lat', 'Lng', 'TimeZone', 'Job', 'Item1', 'Item2',
       'Item3', 'Item4', 'Item5', 'Item6', 'Item7', 'Item8'])
print("DF Shape (Rows,Columns)=", df.shape)
# Out:
# DF Shape (Rows,Columns)= (10000, 30)

# %% [markdown]
# # Handling Missing Values
# KNN is sensitive to missing data because distance calculations require complete data.

# %%
def checkMisisngValues():
    nullseries = df.isna().sum().sort_values()
    print("\n Null Values: ", (nullseries[nullseries > 0]))
checkMisisngValues()
# Out:
#  Null Values:  InternetService    2129
# dtype: int64

# %%
print("InternetService=",df['InternetService'].unique())
df['InternetService'].describe(include='object')
# Out:
# InternetService= ['Fiber Optic' 'DSL' nan]
# count            7871
# unique              2
# top       Fiber Optic
# freq             4408
# Name: InternetService, dtype: object

# %%
#Input missing values using the most frequent category (mode)
df['InternetService'].fillna(df['InternetService'].mode()[0], inplace=True)

utils.writeDFToFile(df, "df_info_1_NoMissingValues.txt")

checkMisisngValues()
# Out:
# Complete details in df_info_1_NoMissingValues.txt file
#
#  Null Values:  Series([], dtype: int64)
# /var/folders/9f/8tw205ns3136cylcf2160v6c0000gn/T/ipykernel_98481/1463085296.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['InternetService'].fillna(df['InternetService'].mode()[0], inplace=True)

# %% [markdown]
# # Data Encoding | One Hot Encoder
# ## Convert Categorical into binary
#
# In Linear and Logistic regression this causes multicollinearity problems, so we ommit one dummy, and it can be inferred from the combination of the other values. KNN and other methods do not have this issue. (drop_first=False)

# %%
# Select Categorical Features
categorical_features = df.select_dtypes(include=['object']).columns.to_list()
print("\ncategorical_feature: qnt_categories")
for column_name in categorical_features:
    print(column_name,":", df[column_name].nunique())
print("\n")
# Out:
# categorical_feature: qnt_categories
# Area : 3
# Marital : 5
# Gender : 3
# Churn : 2
# Techie : 2
# Contract : 3
# Port_modem : 2
# Tablet : 2
# InternetService : 2
# Phone : 2
# Multiple : 2
# OnlineSecurity : 2
# OnlineBackup : 2
# DeviceProtection : 2
# TechSupport : 2
# StreamingTV : 2
# StreamingMovies : 2
# PaperlessBilling : 2
# PaymentMethod : 4

# %%
df = pd.get_dummies(data=df, columns=categorical_features, drop_first=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 38 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Population                             10000 non-null  int64
#  1   Children                               10000 non-null  int64
#  2   Age                                    10000 non-null  int64
#  3   Income                                 10000 non-null  float64
#  4   Outage_sec_perweek                     10000 non-null  float64
#  5   Email                                  10000 non-null  int64
#  6   Contacts                               10000 non-null  int64
#  7   Yearly_equip_failure                   10000 non-null  int64
#  8   Tenure                                 10000 non-null  float64
#  9   MonthlyCharge                          10000 non-null  float64
#  10  Bandwidth_GB_Year                      10000 non-null  float64
#  11  Area_Suburban                          10000 non-null  bool
#  12  Area_Urban                             10000 non-null  bool
#  13  Marital_Married                        10000 non-null  bool
#  14  Marital_Never Married                  10000 non-null  bool
#  15  Marital_Separated                      10000 non-null  bool
#  16  Marital_Widowed                        10000 non-null  bool
#  17  Gender_Male                            10000 non-null  bool
#  18  Gender_Nonbinary                       10000 non-null  bool
#  19  Churn_Yes                              10000 non-null  bool
#  20  Techie_Yes                             10000 non-null  bool
#  21  Contract_One year                      10000 non-null  bool
#  22  Contract_Two Year                      10000 non-null  bool
#  23  Port_modem_Yes                         10000 non-null  bool
#  24  Tablet_Yes                             10000 non-null  bool
#  25  InternetService_Fiber Optic            10000 non-null  bool
#  26  Phone_Yes                              10000 non-null  bool
#  27  Multiple_Yes                           10000 non-null  bool
#  28  OnlineSecurity_Yes                     10000 non-null  bool
#  29  OnlineBackup_Yes                       10000 non-null  bool
#  30  DeviceProtection_Yes                   10000 non-null  bool
#  31  TechSupport_Yes                        10000 non-null  bool
#  32  StreamingTV_Yes                        10000 non-null  bool
#  33  StreamingMovies_Yes                    10000 non-null  bool
#  34  PaperlessBilling_Yes                   10000 non-null  bool
#  35  PaymentMethod_Credit Card (automatic)  10000 non-null  bool
#  36  PaymentMethod_Electronic Check         10000 non-null  bool
#  37  PaymentMethod_Mailed Check             10000 non-null  bool
# dtypes: bool(27), float64(5), int64(6)
# memory usage: 1.1 MB

# %%
print(df.columns)
# Out:
# Index(['Population', 'Children', 'Age', 'Income', 'Outage_sec_perweek',
#        'Email', 'Contacts', 'Yearly_equip_failure', 'Tenure', 'MonthlyCharge',
#        'Bandwidth_GB_Year', 'Area_Suburban', 'Area_Urban', 'Marital_Married',
#        'Marital_Never Married', 'Marital_Separated', 'Marital_Widowed',
#        'Gender_Male', 'Gender_Nonbinary', 'Churn_Yes', 'Techie_Yes',
#        'Contract_One year', 'Contract_Two Year', 'Port_modem_Yes',
#        'Tablet_Yes', 'InternetService_Fiber Optic', 'Phone_Yes',
#        'Multiple_Yes', 'OnlineSecurity_Yes', 'OnlineBackup_Yes',
#        'DeviceProtection_Yes', 'TechSupport_Yes', 'StreamingTV_Yes',
#        'StreamingMovies_Yes', 'PaperlessBilling_Yes',
#        'PaymentMethod_Credit Card (automatic)',
#        'PaymentMethod_Electronic Check', 'PaymentMethod_Mailed Check'],
#       dtype='object')

# %% [markdown]
# # Fix Data Types
# Change bool type to int64 -> True/False -> 1/0

# %%
bool_columns_array = df.select_dtypes(include=['bool']).columns.to_list()
print(bool_columns_array)

for item in bool_columns_array:
    # convert Dtype from 'bool' to 'int64'
    df[item] = df[item].astype('int64')

print("\n")
df.info()
utils.writeDFToFile(df, "df_info_2_Transformed.txt")
df.to_csv('churn_2_Transformed.csv')

# Clear variables
del bool_columns_array, item
# Out:
# ['Area_Suburban', 'Area_Urban', 'Marital_Married', 'Marital_Never Married', 'Marital_Separated', 'Marital_Widowed', 'Gender_Male', 'Gender_Nonbinary', 'Churn_Yes', 'Techie_Yes', 'Contract_One year', 'Contract_Two Year', 'Port_modem_Yes', 'Tablet_Yes', 'InternetService_Fiber Optic', 'Phone_Yes', 'Multiple_Yes', 'OnlineSecurity_Yes', 'OnlineBackup_Yes', 'DeviceProtection_Yes', 'TechSupport_Yes', 'StreamingTV_Yes', 'StreamingMovies_Yes', 'PaperlessBilling_Yes', 'PaymentMethod_Credit Card (automatic)', 'PaymentMethod_Electronic Check', 'PaymentMethod_Mailed Check']
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 38 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Population                             10000 non-null  int64
#  1   Children                               10000 non-null  int64
#  2   Age                                    10000 non-null  int64
#  3   Income                                 10000 non-null  float64
#  4   Outage_sec_perweek                     10000 non-null  float64
#  5   Email                                  10000 non-null  int64
#  6   Contacts                               10000 non-null  int64
#  7   Yearly_equip_failure                   10000 non-null  int64
#  8   Tenure                                 10000 non-null  float64
#  9   MonthlyCharge                          10000 non-null  float64
#  10  Bandwidth_GB_Year                      10000 non-null  float64
#  11  Area_Suburban                          10000 non-null  int64
#  12  Area_Urban                             10000 non-null  int64
#  13  Marital_Married                        10000 non-null  int64
#  14  Marital_Never Married                  10000 non-null  int64
#  15  Marital_Separated                      10000 non-null  int64
#  16  Marital_Widowed                        10000 non-null  int64
#  17  Gender_Male                            10000 non-null  int64
#  18  Gender_Nonbinary                       10000 non-null  int64
#  19  Churn_Yes                              10000 non-null  int64
#  20  Techie_Yes                             10000 non-null  int64
#  21  Contract_One year                      10000 non-null  int64
#  22  Contract_Two Year                      10000 non-null  int64
#  23  Port_modem_Yes                         10000 non-null  int64
#  24  Tablet_Yes                             10000 non-null  int64
#  25  InternetService_Fiber Optic            10000 non-null  int64
#  26  Phone_Yes                              10000 non-null  int64
#  27  Multiple_Yes                           10000 non-null  int64
#  28  OnlineSecurity_Yes                     10000 non-null  int64
#  29  OnlineBackup_Yes                       10000 non-null  int64
#  30  DeviceProtection_Yes                   10000 non-null  int64
#  31  TechSupport_Yes                        10000 non-null  int64
#  32  StreamingTV_Yes                        10000 non-null  int64
#  33  StreamingMovies_Yes                    10000 non-null  int64
#  34  PaperlessBilling_Yes                   10000 non-null  int64
#  35  PaymentMethod_Credit Card (automatic)  10000 non-null  int64
#  36  PaymentMethod_Electronic Check         10000 non-null  int64
#  37  PaymentMethod_Mailed Check             10000 non-null  int64
# dtypes: float64(5), int64(33)
# memory usage: 2.9 MB
#
# Complete details in df_info_2_Transformed.txt file

# %% [markdown]
# # Sampling Data

# %%
def sample_data(df):
    # 80% Trainig sample , 30% Test sample
    target = 'MonthlyCharge'
    Y = df[target] #target
    X = df.drop(target, axis=1) #Predictors
    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
    print('x_train:', x_train.shape)
    print('y_train:', y_train.shape)
    print('x_test:', x_test.shape)
    print('y_test:', y_test.shape)
    return X, Y, x_train, x_test, y_train, y_test
X, Y, x_train, x_test, y_train, y_test = sample_data(df)
# Out:
# x_train: (7000, 37)
# y_train: (7000,)
# x_test: (3000, 37)
# y_test: (3000,)

# %% [markdown]
# # Build Tree Model

# %%
def build_tree_model(x_train, x_test, y_train, y_test):
    # Create Decision Tree classifer object
    regressor = DecisionTreeRegressor(max_depth= 4, 
                                 ccp_alpha=0.05,
                                 random_state=42)

    # Train Decision Tree Classifer
    regressor = regressor.fit(x_train,y_train)

    #Predict the response for test dataset
    y_predicted = regressor.predict(x_test)

    # MAE -> Measures the average absolute difference between predicted and actual values. (Lower is better)
    mae = metrics.mean_absolute_error(y_test, y_predicted)
    print(f"Mean Absolute Error: {mae}")

    # MSE -> Mean Squared Error. Penalizes larger errors more than MAE
    mse = metrics.mean_squared_error(y_test, y_predicted)
    print(f"Mean Squared Error: {mse:.4f}")

    # RMSE -> Root Mean Squared Error. Is more interpretable because it has the same unit as the target variable.
    rmse = mse ** 0.5  # Square root of MSE
    print(f"Root Mean Squared Error: {rmse}")

    # R² Score (Coefficient of Determination) -> Measures how well the model explains variance in the target variable. [0,1] (Higher is better)
    r2 = metrics.r2_score(y_test, y_predicted)
    print(f"R² Score: {r2}")

    train_r2 = regressor.score(x_train, y_train)
    test_r2 = regressor.score(x_test, y_test)
    print(f"Train R²: {train_r2}")
    print(f"Test R²: {test_r2}")
    if train_r2 > test_r2 : print("Overfitting Alert! Train R² ≫ Test R² -> Model is too complex and needs pruning") 
   
    return regressor, y_predicted
regressor, y_predicted = build_tree_model(x_train, x_test, y_train, y_test)
# Out:
# Mean Absolute Error: 13.201775808157342
# Mean Squared Error: 247.9619
# Root Mean Squared Error: 15.74680491066609
# R² Score: 0.8679509136474834
# Train R²: 0.8661567287735613
# Test R²: 0.8679509136474834

# %% [markdown]
# {ccp_alpha': Non-negative float, default=0.0 (Complexity param for cost-complexity pruning)
#
#  'class_weight': default=None (in case we have one feature that is more important)
#
#  'criterion': {'absolute_error', 'squared_error', 'poisson', 'friedman_mse'}
#
#  'splitter': 'best' or 'random'
#
#  'max_depth': int, default=None,
#
#  'min_samples_split': int or float, default=2,
#
#  'min_samples_leaf': int or float, default=1,
#
#  'max_features': default=None,
#
#  'random_state': default=None,
#
#  'max_leaf_nodes': None,
#
#  'min_impurity_decrease': 0.0,
#
#  'min_weight_fraction_leaf': 0.0,
#
#  'monotonic_cst': None,
#  '
#  }

# %%
regressor.get_params()
# Out:
# {'ccp_alpha': 0.05,
#  'criterion': 'squared_error',
#  'max_depth': 4,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': 42,
#  'splitter': 'best'}

# %% [markdown]
# ## Features Importance

# %%
feature_names = X.columns
feature_importance = pd.DataFrame(regressor.feature_importances_, index=feature_names, columns=['importance'])
feature_importance = feature_importance.sort_values ('importance', ascending=False)
feature_importance
# Out:
#                                        importance
# StreamingMovies_Yes                      0.423543
# StreamingTV_Yes                          0.321574
# Multiple_Yes                             0.174728
# OnlineBackup_Yes                         0.080155
# OnlineSecurity_Yes                       0.000000
# Contract_Two Year                        0.000000
# Port_modem_Yes                           0.000000
# Tablet_Yes                               0.000000
# InternetService_Fiber Optic              0.000000
# Phone_Yes                                0.000000
# Population                               0.000000
# Techie_Yes                               0.000000
# DeviceProtection_Yes                     0.000000
# TechSupport_Yes                          0.000000
# PaperlessBilling_Yes                     0.000000
# PaymentMethod_Credit Card (automatic)    0.000000
# PaymentMethod_Electronic Check           0.000000
# Contract_One year                        0.000000
# Churn_Yes                                0.000000
# Children                                 0.000000
# Gender_Nonbinary                         0.000000
# Age                                      0.000000
# Income                                   0.000000
# Outage_sec_perweek                       0.000000
# Email                                    0.000000
# Contacts                                 0.000000
# Yearly_equip_failure                     0.000000
# Tenure                                   0.000000
# Bandwidth_GB_Year                        0.000000
# Area_Suburban                            0.000000
# Area_Urban                               0.000000
# Marital_Married                          0.000000
# Marital_Never Married                    0.000000
# Marital_Separated                        0.000000
# Marital_Widowed                          0.000000
# Gender_Male                              0.000000
# PaymentMethod_Mailed Check               0.000000

# %%
features = list(feature_importance[feature_importance['importance']>0.00].index)
features
# Out:
# ['StreamingMovies_Yes', 'StreamingTV_Yes', 'Multiple_Yes', 'OnlineBackup_Yes']

# %%
feature_importance.head(10).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Keep only most relevant features

# %%
df_filtered = df[['MonthlyCharge', 'StreamingMovies_Yes', 'StreamingTV_Yes', 'Multiple_Yes', 'OnlineBackup_Yes']]
print("DF Shape (Rows,Columns)=", df_filtered.shape)
# Out:
# DF Shape (Rows,Columns)= (10000, 5)

# %% [markdown]
# # Re-run model

# %%
X, Y, x_train, x_test, y_train, y_test = sample_data(df_filtered)
regressor_1, y_predicted = build_tree_model(x_train, x_test, y_train, y_test)
# Out:
# x_train: (7000, 4)
# y_train: (7000,)
# x_test: (3000, 4)
# y_test: (3000,)
# Mean Absolute Error: 13.201775808157342
# Mean Squared Error: 247.9619
# Root Mean Squared Error: 15.746804910666087
# R² Score: 0.8679509136474834
# Train R²: 0.8661567287735613
# Test R²: 0.8679509136474834

# %% [markdown]
# # Show tree

# %%
from sklearn import tree

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(regressor_1,
                   feature_names=features,
                   filled=True,
                   rounded=True,
                   fontsize=10
                   )

# %%
print("\nTP | FP \nFN | TN \n")
mtx = metrics.confusion_matrix(regressor_1.p
utils.plot_confusion_matrix(mtx)
# Out:
# TP | FP
# FN | TN
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 print("\nTP | FP \nFN | TN \n")
# ----> 2 mtx = metrics.confusion_matrix(y_test, y_predicted)
#       3 utils.plot_confusion_matrix(mtx)
#
# File ~/Documents/CodeProjects/WGU/.venv/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~/Documents/CodeProjects/WGU/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:340, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     257 """Compute confusion matrix to evaluate the accuracy of a classification.
#     258
#     259 By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     337 (np.int64(0), np.int64(2), np.int64(1), np.int64(1))
#     338 """
#     339 y_true, y_pred = attach_unique(y_true, y_pred)
# --> 340 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     341 if y_type not in ("binary", "multiclass"):
#     342     raise ValueError("%s is not supported" % y_type)
#
# File ~/Documents/CodeProjects/WGU/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:118, in _check_targets(y_true, y_pred)
#     116 # No metrics support "multiclass-multioutput" format
#     117 if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 118     raise ValueError("{0} is not supported".format(y_type))
#     120 if y_type in ["binary", "multiclass"]:
#     121     xp, _ = get_namespace(y_true, y_pred)
#
# ValueError: continuous is not supported
