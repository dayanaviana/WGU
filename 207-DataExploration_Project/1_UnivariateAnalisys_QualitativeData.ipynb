# %% [markdown]
# # Load dataset

# %%
from operator import index
# import into data frame
import pandas as pd
churn = "https://raw.githubusercontent.com/dayanaviana/WGU/main/datasources/churn_clean.csv"
df = pd.read_csv(churn, index_col=0)

categorical_columns_array = [
                 "Churn",
                #  "City",
                # "State",
                #  "County",
                 "Area",
                 "Marital",
                 "Gender",
                 "Techie",
                 "InternetService",
                 "Multiple",
                 "OnlineBackup",
                 "DeviceProtection",
                 "StreamingTV",
                 "StreamingMovies",
                 "Port_modem",
                 "Tablet",
                 "OnlineSecurity",
                 "TechSupport",
                 "Contract",
                 "PaperlessBilling",
                 "PaymentMethod",
                 "TimeZone",
                 "Item1",
                 "Item2",
                 "Item3",
                 "Item4",
                 "Item5",
                 "Item6",
                 "Item7",
                 "Item8",
                #  "Job",
                 ]

# %% [markdown]
# # Descriptive Statistics
# Describe and summarize data

# %%
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np

for column_name in categorical_columns_array:
  print("\n")
  print(column_name)

  sample = df.loc[:, column_name]
  categories = np.unique(sample)
  categories_counts = sample.value_counts()
  percentages = df[column_name].value_counts(dropna=False, normalize=True)

  #Performing Chi-square test
  # H0: NO statistic significant difference between groups
  # H1: Correlation exists
  chisquareResult = stats.chisquare(categories_counts)
  print("Chi-square test: ", chisquareResult)
  statistic, pValue = chisquareResult

  #Interpret p-value
  #P-value is the probability of H0 being true
  alpha = 0.05
  if pValue <= alpha:
    h0 = False # Reject H0
  else:
    h0 = True # Accept H0

  if (h0):
    print("Categories have SAME distribution")
  else:
    print("Categories have DIFFERENT distribution")
  
  # Build DF for Bar graph
  # custom_index = ['Row'+str(i) for i in range(1, len(categories_counts.values)+1)]
  custom_df = pd.DataFrame(categories_counts)
  custom_df['Percentage'] = percentages
  # Transfrom index as a column
  custom_df.reset_index(level=0, inplace=True)
  # Rename columns
  custom_df.rename(columns = {list(custom_df)[0]:'Category'}, inplace=True)
  custom_df.rename(columns = {list(custom_df)[1]:'Count'}, inplace=True)
  print(custom_df)
  print("\n")


  # Bar Graph
  # https://medium.com/@jb.ranchana/easy-way-to-create-stacked-bar-graphs-from-dataframe-19cc97c86fe3

  # fig = plt.figure()
  # ax = fig.add_axes([0,0,1,1])

  bar_graph = plt.bar(x=custom_df['Category'], 
        height=custom_df['Count'],
        color='lightseagreen', #https://matplotlib.org/3.1.0/gallery/color/named_colors.html
        #width = 0.5
        )
  plt.ylabel("Counts")
  plt.xlabel("Category")
  plt.title(column_name)

  # Add counts above the graph
  for rect in bar_graph:
      x = rect.get_x()
      height = rect.get_height()
      plt.text(x=rect.get_x() + rect.get_width() / 2, y=height+.10,
      s="{}".format(height),
      ha='center', 
      va='bottom')


  plt.show()
# Out:
# Churn
# Chi-square test:  Power_divergenceResult(statistic=2209.0, pvalue=0.0)
# Categories have DIFFERENT distribution
#   Category  Count  Percentage
# 0       No   7350       0.735
# 1      Yes   2650       0.265
# Area
# Chi-square test:  Power_divergenceResult(statistic=0.07219999999999999, pvalue=0.9645438342768154)
# Categories have SAME distribution
#    Category  Count  Percentage
# 0  Suburban   3346      0.3346
# 1     Urban   3327      0.3327
# 2     Rural   3327      0.3327
# Marital
# Chi-square test:  Power_divergenceResult(statistic=9.623, pvalue=0.04728031294668998)
# Categories have DIFFERENT distribution
#         Category  Count  Percentage
# 0       Divorced   2092      0.2092
# 1        Widowed   2027      0.2027
# 2      Separated   2014      0.2014
# 3  Never Married   1956      0.1956
# 4        Married   1911      0.1911
# Gender
# Chi-square test:  Power_divergenceResult(statistic=4342.856599999999, pvalue=0.0)
# Categories have DIFFERENT distribution
#     Category  Count  Percentage
# 0     Female   5025      0.5025
# 1       Male   4744      0.4744
# 2  Nonbinary    231      0.0231
# Techie
# Chi-square test:  Power_divergenceResult(statistic=4411.6164, pvalue=0.0)
# Categories have DIFFERENT distribution
#   Category  Count  Percentage
# 0       No   8321      0.8321
# 1      Yes   1679      0.1679
# InternetService
# Chi-square test:  Power_divergenceResult(statistic=786.6422, pvalue=1.523409480186182e-171)
# Categories have DIFFERENT distribution
#       Category  Count  Percentage
# 0  Fiber Optic   4408      0.4408
# 1          DSL   3463      0.3463
# 2         None   2129      0.2129
# Multiple
# Chi-square test:  Power_divergenceResult(statistic=61.4656, pvalue=4.505464303932248e-15)
# Categories have DIFFERENT distribution
#   Category  Count  Percentage
# 0       No   5392      0.5392
# 1      Yes   4608      0.4608
# OnlineBackup
# Chi-square test:  Power_divergenceResult(statistic=97.6144, pvalue=5.0832909799077264e-23)
# Categories have DIFFERENT distribution
#   Category  Count  Percentage
# 0       No   5494      0.5494
# 1      Yes   4506      0.4506
# DeviceProtection
# Chi-square test:  Power_divergenceResult(statistic=150.7984, pvalue=1.159982615467555e-34)
# Categories have DIFFERENT distribution
#   Category  Count  Percentage
# 0       No   5614      0.5614
# 1      Yes   4386      0.4386
# StreamingTV
# Chi-square test:  Power_divergenceResult(statistic=2.0164, pvalue=0.15560768105308867)
# Categories have SAME distribution
#   Category  Count  Percentage
# 0       No   5071      0.5071
# 1      Yes   4929      0.4929
# StreamingMovies
# Chi-square test:  Power_divergenceResult(statistic=4.84, pvalue=0.027806895026997264)
# Categories have DIFFERENT distribution
#   Category  Count  Percentage
# 0       No   5110       0.511
# 1      Yes   4890       0.489
# Port_modem
# Chi-square test:  Power_divergenceResult(statistic=11.0224, pvalue=0.0009001744811842354)
# Categories have DIFFERENT distribution
#   Category  Count  Percentage
# 0       No   5166      0.5166
# 1      Yes   4834      0.4834
# Tablet
# Chi-square test:  Power_divergenceResult(statistic=1614.4324, pvalue=0.0)
# Categories have DIFFERENT distribution
#   Category  Count  Percentage
# 0       No   7009      0.7009
# 1      Yes   2991      0.2991
# OnlineSecurity
# Chi-square test:  Power_divergenceResult(statistic=811.1104, pvalue=2.0724345203754966e-178)
# Categories have DIFFERENT distribution
#   Category  Count  Percentage
# 0       No   6424      0.6424
# 1      Yes   3576      0.3576
# TechSupport
# Chi-square test:  Power_divergenceResult(statistic=625.0, pvalue=6.113393412765105e-138)
# Categories have DIFFERENT distribution
#   Category  Count  Percentage
# 0       No   6250       0.625
# 1      Yes   3750       0.375
# Contract
# Chi-square test:  Power_divergenceResult(statistic=2044.9112, pvalue=0.0)
# Categories have DIFFERENT distribution
#          Category  Count  Percentage
# 0  Month-to-month   5456      0.5456
# 1        Two Year   2442      0.2442
# 2        One year   2102      0.2102
# PaperlessBilling
# Chi-square test:  Power_divergenceResult(statistic=311.1696, pvalue=1.2146096518734042e-69)
# Categories have DIFFERENT distribution
#   Category  Count  Percentage
# 0      Yes   5882      0.5882
# 1       No   4118      0.4118
# PaymentMethod
# Chi-square test:  Power_divergenceResult(statistic=439.1336, pvalue=7.371814027426512e-95)
# Categories have DIFFERENT distribution
#                    Category  Count  Percentage
# 0          Electronic Check   3398      0.3398
# 1              Mailed Check   2290      0.2290
# 2  Bank Transfer(automatic)   2229      0.2229
# 3   Credit Card (automatic)   2083      0.2083
# TimeZone
# Chi-square test:  Power_divergenceResult(statistic=68204.165, pvalue=0.0)
# Categories have DIFFERENT distribution
#                           Category  Count  Percentage
# 0                 America/New_York   4072      0.4072
# 1                  America/Chicago   3672      0.3672
# 2              America/Los_Angeles    887      0.0887
# 3                   America/Denver    552      0.0552
# 4                  America/Detroit    265      0.0265
# 5     America/Indiana/Indianapolis    186      0.0186
# 6                  America/Phoenix    104      0.0104
# 7                    America/Boise     57      0.0057
# 8                America/Anchorage     55      0.0055
# 9              America/Puerto_Rico     40      0.0040
# 10                Pacific/Honolulu     35      0.0035
# 11               America/Menominee     16      0.0016
# 12                    America/Nome     12      0.0012
# 13     America/Kentucky/Louisville     10      0.0010
# 14                   America/Sitka      8      0.0008
# 15       America/Indiana/Vincennes      6      0.0006
# 16       America/Indiana/Tell_City      6      0.0006
# 17                 America/Toronto      5      0.0005
# 18      America/Indiana/Petersburg      4      0.0004
# 19                  America/Juneau      2      0.0002
# 20  America/North_Dakota/New_Salem      2      0.0002
# 21            America/Indiana/Knox      1      0.0001
# 22         America/Indiana/Winamac      1      0.0001
# 23         America/Indiana/Marengo      1      0.0001
# 24                 America/Ojinaga      1      0.0001
# Item1
# Chi-square test:  Power_divergenceResult(statistic=8929.635199999999, pvalue=0.0)
# Categories have DIFFERENT distribution
#    Category  Count  Percentage
# 0         3   3448      0.3448
# 1         4   3358      0.3358
# 2         2   1393      0.1393
# 3         5   1359      0.1359
# 4         1    224      0.0224
# 5         6    199      0.0199
# 6         7     19      0.0019
# Item2
# Chi-square test:  Power_divergenceResult(statistic=8982.9332, pvalue=0.0)
# Categories have DIFFERENT distribution
#    Category  Count  Percentage
# 0         3   3415      0.3415
# 1         4   3412      0.3412
# 2         5   1368      0.1368
# 3         2   1360      0.1360
# 4         1    217      0.0217
# 5         6    215      0.0215
# 6         7     13      0.0013
# Item3
# Chi-square test:  Power_divergenceResult(statistic=11808.9824, pvalue=0.0)
# Categories have DIFFERENT distribution
#    Category  Count  Percentage
# 0         3   3435      0.3435
# 1         4   3410      0.3410
# 2         2   1424      0.1424
# 3         5   1313      0.1313
# 4         6    203      0.0203
# 5         1    202      0.0202
# 6         7     12      0.0012
# 7         8      1      0.0001
# Item4
# Chi-square test:  Power_divergenceResult(statistic=9163.241999999998, pvalue=0.0)
# Categories have DIFFERENT distribution
#    Category  Count  Percentage
# 0         4   3452      0.3452
# 1         3   3430      0.3430
# 2         2   1350      0.1350
# 3         5   1335      0.1335
# 4         1    221      0.0221
# 5         6    203      0.0203
# 6         7      9      0.0009
# Item5
# Chi-square test:  Power_divergenceResult(statistic=9172.6178, pvalue=0.0)
# Categories have DIFFERENT distribution
#    Category  Count  Percentage
# 0         3   3462      0.3462
# 1         4   3417      0.3417
# 2         2   1378      0.1378
# 3         5   1321      0.1321
# 4         1    206      0.0206
# 5         6    204      0.0204
# 6         7     12      0.0012
# Item6
# Chi-square test:  Power_divergenceResult(statistic=11602.8096, pvalue=0.0)
# Categories have DIFFERENT distribution
#    Category  Count  Percentage
# 0         3   3445      0.3445
# 1         4   3333      0.3333
# 2         2   1427      0.1427
# 3         5   1382      0.1382
# 4         6    210      0.0210
# 5         1    190      0.0190
# 6         7     12      0.0012
# 7         8      1      0.0001
# Item7
# Chi-square test:  Power_divergenceResult(statistic=9188.9712, pvalue=0.0)
# Categories have DIFFERENT distribution
#    Category  Count  Percentage
# 0         4   3456      0.3456
# 1         3   3446      0.3446
# 2         5   1335      0.1335
# 3         2   1309      0.1309
# 4         6    224      0.0224
# 5         1    219      0.0219
# 6         7     11      0.0011
# Item8
# Chi-square test:  Power_divergenceResult(statistic=11843.430400000001, pvalue=0.0)
# Categories have DIFFERENT distribution
#    Category  Count  Percentage
# 0         3   3461      0.3461
# 1         4   3400      0.3400
# 2         2   1378      0.1378
# 3         5   1335      0.1335
# 4         1    206      0.0206
# 5         6    205      0.0205
# 6         7     14      0.0014
# 7         8      1      0.0001

# %%
df['Gender'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of CaseOrder
# 1          Male
# 2        Female
# 3        Female
# 4          Male
# 5          Male
#           ...
# 9996       Male
# 9997       Male
# 9998     Female
# 9999       Male
# 10000      Male
# Name: Gender, Length: 10000, dtype: object>

# %%
import numpy as np

# source: https://medium.com/@jb.ranchana/easy-way-to-create-stacked-bar-graphs-from-dataframe-19cc97c86fe3


df_filtered = df.loc[:, 'Gender']

# Bar Graph
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
categories = np.unique(df_filtered)
print(categories)
counts = df_filtered.value_counts().values
print(counts)

ax.bar(x=categories, 
       height=counts,
       color='navy'
       )
plt.show()
# Out:
# ['Female' 'Male' 'Nonbinary']
# [5025 4744  231]

# %% [markdown]
# # Insigts
