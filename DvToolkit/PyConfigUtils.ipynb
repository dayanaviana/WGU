# %%
! pip install import-ipynb

# %%
from platform import python_version
print(python_version())

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation eg:confusion_matrix, classification_report, roc_auc_score, mean_squared_error

# %%
! pip install numpy

# %%
! pip install scikit-learn

# %%
! pip install mlxtend
# Out:
# Collecting mlxtend
#   Using cached mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.16.3 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=2.3.5 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from mlxtend) (2.3.5)
# Requirement already satisfied: pandas>=2.3.3 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from mlxtend) (2.3.3)
# Collecting scikit-learn>=1.8.0 (from mlxtend)
#   Using cached scikit_learn-1.8.0-cp314-cp314-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting matplotlib>=3.10.8 (from mlxtend)
#   Using cached matplotlib-3.10.9-cp314-cp314-macosx_11_0_arm64.whl.metadata (52 kB)
# Requirement already satisfied: joblib>=1.5.2 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/dayanaviana/Documents/CodeProjects/WGU/.venv-py314/lib/python3.14/site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Using cached mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
# Using cached matplotlib-3.10.9-cp314-cp314-macosx_11_0_arm64.whl (8.2 MB)
# Using cached scikit_learn-1.8.0-cp314-cp314-macosx_12_0_arm64.whl (8.1 MB)
# Installing collected packages: scikit-learn, matplotlib, mlxtend
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.7.2
#     Uninstalling scikit-learn-1.7.2:
#       Successfully uninstalled scikit-learn-1.7.2
#   Attempting uninstall: matplotlib━━━━━━━━━━━━━━ 0/3 [scikit-learn]
#     Found existing installation: matplotlib 3.10.70/3 [scikit-learn]
#     Uninstalling matplotlib-3.10.7:━━━━━━━━━ 0/3 [scikit-learn]
#       Successfully uninstalled matplotlib-3.10.7━━━━━━━━━━━━━━━━━━ 1/3 [matplotlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [mlxtend]m2/3 [mlxtend]ib]
# Successfully installed matplotlib-3.10.9 mlxtend-0.24.0 scikit-learn-1.8.0

# %%
! pip uninstall google-colab

# %%
# WARNING: You are using pip version 21.1.3; however, version 22.1.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
! pip install --upgrade pip
