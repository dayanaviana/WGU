# %%
#churn_clean_altered.csv
docId= "1-WjyGAwXhgkEMSGk1PHKMjIASkVgn-YO"
googleDriveFile = "https://docs.google.com/uc?id="+docId+"&export=download"

# import into data frame
import pandas as pd
df = pd.read_csv(googleDriveFile, index_col=0)

# %% [markdown]
# # Descriptive Statistics
# Describe and summarize data

# %% [markdown]
# ## Numeric (Quantitative)

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt 
import plotnine as p9

columns_array = ["Income", 
                 "Tenure", 
                 "Outage_sec_perweek", 
                 "MonthlyCharge", 
                 "Bandwidth_GB_Year",
                 "Population",
                 "Children",
                 "Age",
                 "Yearly_equip_failure",
                 "Email",
                 "Contacts"
                 ]

for column_name in columns_array:
  print("\n")
  print(column_name)
  sample = df[column_name]
  max = np.max(sample)
  print("Max:", max)
  min = np.min(sample)
  print("Min:", min)
  mean = "{:.2f}".format(np.mean(sample))
  print("Mean:", mean)
  median =  "{:.2f}".format(np.median(sample))
  print("Median:", median)

  # Python 3.8
  # import statistics
  # mode =  statistics.multimode(sample)
  mode =  stats.mode(sample)
  print("Mode:", mode[0])
  
  var =  "{:.2f}".format(np.var(sample))
  print("Variance:", var)
  stddev =  "{:.2f}".format(np.std(sample))
  print("St. Dev:", stddev)

  # Histogram, Boxplot and density plot 
  # Plot size: 1900px x 800px
  plt.subplots(figsize=(18, 6))

  # configure supplot(nrows,ncols,nsubplots) 
  plt.subplot(1,3,1) 
  plt.grid(True)
  plt.title("Histogram")
  plt.hist(sample) 

  plt.subplot(1,3,2) 
  plt.grid(True)
  plt.title("Boxplot")
  plt.boxplot(sample) 
  
  plt.subplot(1,3,3) 
  plt.grid(True)
  plt.title("Distribution")
  sample.plot.density()

  plt.show() 

  # Test normality -> Run Shapiro-Wilk test
  testResult = stats.shapiro(sample)
  statistic, pvalue = testResult
  print("Shapiro-Wilk test: ", testResult)
  if(pvalue < 0.05 and statistic > 0.95):
    print("NORMAL Distribution")
  else:
    print("Not certain of normality")
# Out:
# Income
# Max: 258900.7
# Min: 348.67
# Mean: 39806.93
# Median: 33170.60
# Mode: [10530.09]
# Variance: 795155778.45
# St. Dev: 28198.51
# /usr/local/lib/python3.7/dist-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Shapiro-Wilk test:  (0.8934258222579956, 0.0)
# Not certain of normality
#
#
# Tenure
# Max: 72.0
# Min: 1.0
# Mean: 34.53
# Median: 35.45
# Mode: [2.4]
# Variance: 699.17
# St. Dev: 26.44
# /usr/local/lib/python3.7/dist-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Shapiro-Wilk test:  (0.830752968788147, 0.0)
# Not certain of normality
#
#
# Outage_sec_perweek
# Max: 21.2
# Min: 0.1
# Mean: 10.00
# Median: 10.00
# Mode: [9.]
# Variance: 8.86
# St. Dev: 2.98
# /usr/local/lib/python3.7/dist-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Shapiro-Wilk test:  (0.9996834993362427, 0.11164969205856323)
# Not certain of normality
#
#
# MonthlyCharge
# Max: 290.16
# Min: 79.98
# Mean: 172.62
# Median: 167.48
# Mode: [172.46]
# Variance: 1843.91
# St. Dev: 42.94
# /usr/local/lib/python3.7/dist-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Shapiro-Wilk test:  (0.9796310067176819, 1.9951316067649435e-35)
# NORMAL Distribution
#
#
# Bandwidth_GB_Year
# Max: 7159.0
# Min: 155.5
# Mean: 3392.34
# Median: 3279.55
# Mode: [1058.6]
# Variance: 4775035.80
# St. Dev: 2185.19
# /usr/local/lib/python3.7/dist-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Shapiro-Wilk test:  (0.8582527041435242, 0.0)
# Not certain of normality
#
#
# Population
# Max: 111850
# Min: 0
# Mean: 9756.56
# Median: 2910.50
# Mode: [0]
# Variance: 208281960.64
# St. Dev: 14431.98
# /usr/local/lib/python3.7/dist-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Shapiro-Wilk test:  (0.6966826915740967, 0.0)
# Not certain of normality
#
#
# Children
# Max: 10
# Min: 0
# Mean: 2.09
# Median: 1.00
# Mode: [0]
# Variance: 4.61
# St. Dev: 2.15
# /usr/local/lib/python3.7/dist-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Shapiro-Wilk test:  (0.836870014667511, 0.0)
# Not certain of normality
#
#
# Age
# Max: 89
# Min: 18
# Mean: 53.08
# Median: 53.00
# Mode: [32]
# Variance: 428.40
# St. Dev: 20.70
# /usr/local/lib/python3.7/dist-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Shapiro-Wilk test:  (0.9543271064758301, 0.0)
# NORMAL Distribution
#
#
# Yearly_equip_failure
# Max: 6
# Min: 0
# Mean: 0.40
# Median: 0.00
# Mode: [0]
# Variance: 0.40
# St. Dev: 0.64
# /usr/local/lib/python3.7/dist-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Shapiro-Wilk test:  (0.6415181159973145, 0.0)
# Not certain of normality
#
#
# Email
# Max: 23
# Min: 1
# Mean: 12.02
# Median: 12.00
# Mode: [12]
# Variance: 9.16
# St. Dev: 3.03
# /usr/local/lib/python3.7/dist-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# Shapiro-Wilk test:  (0.9906892776489258, 4.795065374406501e-25)
# NORMAL Distribution
#
#
# Contacts
# Max: 7
# Min: 0
# Mean: 0.99
# Median: 1.00
# Mode: [0]
# Variance: 0.98
# St. Dev: 0.99
# Shapiro-Wilk test:  (0.8337748050689697, 0.0)
# Not certain of normality
# /usr/local/lib/python3.7/dist-packages/scipy/stats/morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# # Insigts
#
# - Low **Tenure**: churn clients median stay is 7 months, while non-churn stay for 53 months
#
# - High **MonthlyCharge**: churn clients pay in avg `$`199.29, while non-churn pay `$`163.00
#
# - Low **Bandwidth_GB_Year**: churn clients median use is 1,357.83 GB per year, while non-churn use is 4,895.17 GB per year.
#
# *If data is skewed, MEDIAN is usually better to use *italicized text*
