# %%
import pandas as pd

# import into data frame
data = "https://raw.githubusercontent.com/dayanaviana/WGU/main/datasources/churn_clean.csv"
churn = pd.read_csv(churn_csv, index_col=0)
churn.head(3)
# Out:
#           Customer_id                           Interaction  \
# CaseOrder
# 1             K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# 2             S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
# 3             K191035  344d114c-3736-4be5-98f7-c72c281e2d35
#
#                                         UID         City State  \
# CaseOrder
# 1          e885b299883d4f9fb18e39c75155d990  Point Baker    AK
# 2          f2de8bef964785f41a2959829830fb8a  West Branch    MI
# 3          f1784cfa9f6d92ae816197eb175d3c71      Yamhill    OR
#
#                           County    Zip       Lat        Lng  Population  ...  \
# CaseOrder                                                                 ...
# 1          Prince of Wales-Hyder  99927  56.25100 -133.37571          38  ...
# 2                         Ogemaw  48661  44.32893  -84.24080       10446  ...
# 3                        Yamhill  97148  45.35589 -123.24657        3735  ...
#
# ...

# %%
churn.describe()
# Out:
#                 Zip           Lat           Lng     Population    Children  \
# count  10000.000000  10000.000000  10000.000000   10000.000000  10000.0000
# mean   49153.319600     38.757567    -90.782536    9756.562400      2.0877
# std    27532.196108      5.437389     15.156142   14432.698671      2.1472
# min      601.000000     17.966120   -171.688150       0.000000      0.0000
# 25%    26292.500000     35.341828    -97.082812     738.000000      0.0000
# 50%    48869.500000     39.395800    -87.918800    2910.500000      1.0000
# 75%    71866.500000     42.106908    -80.088745   13168.000000      3.0000
# max    99929.000000     70.640660    -65.667850  111850.000000     10.0000
#
#                 Age         Income  Outage_sec_perweek         Email  \
# count  10000.000000   10000.000000        10000.000000  10000.000000
# mean      53.078400   39806.926771           10.001848     12.016000
# std       20.698882   28199.916702            2.976019      3.025898
# ...

# %%
import matplotlib.pyplot as plt

dataframe = churn
corr = dataframe.corr()
corr.style.background_gradient(cmap='coolwarm')
plt.matshow(corr)
plt.show()

# %%
dataframe.corr()
# Out:
#                                Zip       Lat       Lng  Population  Children  \
# Zip                   1.000000e+00 -0.042580 -0.901786    0.045138 -0.017205
# Lat                  -4.257985e-02  1.000000 -0.100639   -0.220598 -0.000452
# Lng                  -9.017856e-01 -0.100639  1.000000   -0.048294  0.013634
# Population            4.513808e-02 -0.220598 -0.048294    1.000000 -0.005877
# Children             -1.720505e-02 -0.000452  0.013634   -0.005877  1.000000
# Age                  -8.135285e-03 -0.002943  0.012117    0.010538 -0.029732
# Income                2.946523e-03  0.006563 -0.002997   -0.008639  0.009942
# Outage_sec_perweek   -1.152040e-02  0.004827  0.005646    0.005483  0.001889
# Email                -7.860018e-03 -0.030042  0.007872    0.017962  0.004479
# Contacts             -4.719513e-03 -0.002213  0.008118    0.004019 -0.020776
# Yearly_equip_failure  1.104692e-02 -0.007125 -0.005577   -0.004483  0.007321
# ...

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(10, 8))
corr = dataframe.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=np.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
# Out:
# /var/folders/6m/dwz3f9j966d59srjjcwwxjvm0000gp/T/ipykernel_9138/2255616847.py:7: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=np.diverging_palette(220, 10, as_cmap=True))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/6m/dwz3f9j966d59srjjcwwxjvm0000gp/T/ipykernel_9138/2255616847.py in <module>
#       5 f, ax = plt.subplots(figsize=(10, 8))
#       6 corr = dataframe.corr()
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = churn[['Churn','Contract','Techie','Tenure','MonthlyCharge','Bandwidth_GB_Year','StreamingTV','StreamingMovies','InternetService','Phone','Multiple','OnlineSecurity','OnlineBackup','DeviceProtection']]
sns.pairplot(df, kind="scatter")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

sns.catplot(x="Churn", y="Tenure", data=df)
