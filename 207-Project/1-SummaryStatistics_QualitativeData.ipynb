# %%
from operator import index
# import into data frame
import pandas as pd
churn = "https://raw.githubusercontent.com/dayanaviana/WGU/main/datasources/churn_clean.csv"
df = pd.read_csv(churn, index_col=0)

df_churn_yes = df[df["Churn"]=="Yes"]
df_churn_no = df[df["Churn"]=="No"]

# %% [markdown]
# # Descriptive Statistics
# Describe and summarize data

# %% [markdown]
# ## Categorical (Qualitative)

# %%
columns_array = ["Churn",
                 "City",
                 "State",
                 "County",
                 "Area",
                 "Marital",
                 "Gender",
                 "Techie",
                 "InternetService",
                 "Multiple",
                 "OnlineBackup",
                 "DeviceProtection",
                 "StreamingTV",
                 "StreamingMovies",
                 "Port_modem",
                 "Tablet",
                 "OnlineSecurity",
                 "TechSupport",
                 "Contract",
                 "PaperlessBilling",
                 "PaymentMethod",
                 "TimeZone",
                 "Item1",
                 "Item2",
                 "Item3",
                 "Item4",
                 "Item5",
                 "Item6",
                 "Item7",
                 "Item8",
                 "Job",
                 ]

for column_name in columns_array:
  print("\n")
  print(column_name)
  counts = df[column_name].value_counts(dropna=False)
  percentages = df[column_name].value_counts(dropna=False, normalize=True)

  counts_yes = df_churn_yes[column_name].value_counts(dropna=False)
  percentages_yes = df_churn_yes[column_name].value_counts(dropna=False, normalize=True)

  counts_no = df_churn_no[column_name].value_counts(dropna=False)
  percentages_no = df_churn_no[column_name].value_counts(dropna=False, normalize=True)
  
  summary = pd.concat([counts, 
                       percentages*100, 
                       counts_yes, 
                       percentages_yes*100, 
                       counts_no, 
                       percentages_no*100
                       ], 
                      axis=1, 
                      keys=['Counts', '%', '| YES:  Counts', '%', '|NO: Counts', '%',]
                      )
  print(summary)
  print("\n")

  # Histogram and show plot 
  # Plot size: 1200px x 400px
  plt.subplots(figsize=(12, 4))
  # configure supplot(nrows,ncols,nsubplots) 
  plt.subplot(1,3,1) 
  plt.hist(df[column_name]) 
  plt.title(column_name)
  plt.subplot(1,3,2) 
  plt.hist(df_churn_yes[column_name]) 
  plt.title("Churn=YES")
  plt.subplot(1,3,3) 
  plt.hist(df_churn_no[column_name]) 
  plt.title("Churn=NO")
  plt.show()
# Out:
# Churn
#      Counts     %  | YES:  Counts      %  |NO: Counts      %
# No     7350  73.5             NaN    NaN       7350.0  100.0
# Yes    2650  26.5          2650.0  100.0          NaN    NaN
# City
#              Counts     %  | YES:  Counts         %  |NO: Counts         %
# Houston          34  0.34            11.0  0.415094         23.0  0.312925
# New York         24  0.24            10.0  0.377358         14.0  0.190476
# Buffalo          23  0.23             6.0  0.226415         17.0  0.231293
# Springfield      23  0.23             8.0  0.301887         15.0  0.204082
# San Antonio      22  0.22             9.0  0.339623         13.0  0.176871
# ...             ...   ...             ...       ...          ...       ...
# Tonto Basin       1  0.01             NaN       NaN          1.0  0.013605
# Bridgeview        1  0.01             NaN       NaN          1.0  0.013605
# Shelton           1  0.01             NaN       NaN          1.0  0.013605
# Alcoa             1  0.01             NaN       NaN          1.0  0.013605
# Fort Drum         1  0.01             NaN       NaN          1.0  0.013605
#
# [6058 rows x 6 columns]
# State
#     Counts     %  | YES:  Counts         %  |NO: Counts         %
# TX     603  6.03             173  6.528302          430  5.850340
# NY     558  5.58             137  5.169811          421  5.727891
# PA     550  5.50             137  5.169811          413  5.619048
# CA     526  5.26             138  5.207547          388  5.278912
# IL     413  4.13             101  3.811321          312  4.244898
# OH     359  3.59              97  3.660377          262  3.564626
# FL     324  3.24              71  2.679245          253  3.442177
# MO     310  3.10              88  3.320755          222  3.020408
# VA     285  2.85              79  2.981132          206  2.802721
# NC     280  2.80              73  2.754717          207  2.816327
# MI     279  2.79              80  3.018868          199  2.707483
# IA     279  2.79              75  2.830189          204  2.775510
# MN     264  2.64              55  2.075472          209  2.843537
# WV     247  2.47              77  2.905660          170  2.312925
# IN     241  2.41              68  2.566038          173  2.353741
# KY     238  2.38              66  2.490566          172  2.340136
# GA     238  2.38              64  2.415094          174  2.367347
# WI     228  2.28              68  2.566038          160  2.176871
# OK     203  2.03              55  2.075472          148  2.013605
# KS     195  1.95              57  2.150943          138  1.877551
# NJ     190  1.90              52  1.962264          138  1.877551
# TN     185  1.85              52  1.962264          133  1.809524
# AL     181  1.81              42  1.584906          139  1.891156
# NE     181  1.81              38  1.433962          143  1.945578
# AR     176  1.76              44  1.660377          132  1.795918
# WA     175  1.75              61  2.301887          114  1.551020
# MA     172  1.72              41  1.547170          131  1.782313
# CO     155  1.55              38  1.433962          117  1.591837
# LA     141  1.41              40  1.509434          101  1.374150
# MS     126  1.26              35  1.320755           91  1.238095
# SC     124  1.24              25  0.943396           99  1.346939
# MD     123  1.23              38  1.433962           85  1.156463
# ND     118  1.18              32  1.207547           86  1.170068
# NM     114  1.14              32  1.207547           82  1.115646
# OR     114  1.14              31  1.169811           83  1.129252
# ME     112  1.12              32  1.207547           80  1.088435
# AZ     112  1.12              29  1.094340           83  1.129252
# SD     101  1.01              24  0.905660           77  1.047619
# MT      96  0.96              29  1.094340           67  0.911565
# NH      85  0.85              20  0.754717           65  0.884354
# VT      84  0.84              23  0.867925           61  0.829932
# ID      81  0.81              18  0.679245           63  0.857143
# AK      77  0.77              23  0.867925           54  0.734694
# CT      71  0.71              25  0.943396           46  0.625850
# UT      66  0.66              17  0.641509           49  0.666667
# NV      48  0.48               8  0.301887           40  0.544218
# WY      43  0.43              11  0.415094           32  0.435374
# PR      40  0.40              10  0.377358           30  0.408163
# HI      35  0.35               6  0.226415           29  0.394558
# DE      21  0.21               6  0.226415           15  0.204082
# RI      19  0.19               2  0.075472           17  0.231293
# DC      14  0.14               7  0.264151            7  0.095238
# County
#              Counts     %  | YES:  Counts         %  |NO: Counts         %
# Washington      111  1.11            32.0  1.207547         79.0  1.074830
# Jefferson       100  1.00            24.0  0.905660         76.0  1.034014
# Montgomery       99  0.99            25.0  0.943396         74.0  1.006803
# Franklin         92  0.92            19.0  0.716981         73.0  0.993197
# Los Angeles      91  0.91            23.0  0.867925         68.0  0.925170
# ...             ...   ...             ...       ...          ...       ...
# Colorado          1  0.01             NaN       NaN          1.0  0.013605
# Shannon           1  0.01             NaN       NaN          1.0  0.013605
# Whitfield         1  0.01             1.0  0.037736          NaN       NaN
# Merrick           1  0.01             NaN       NaN          1.0  0.013605
# Gove              1  0.01             1.0  0.037736          NaN       NaN
#
# [1620 rows x 6 columns]
# Area
#           Counts      %  | YES:  Counts          %  |NO: Counts          %
# Suburban    3346  33.46             873  32.943396         2473  33.646259
# Urban       3327  33.27             914  34.490566         2413  32.829932
# Rural       3327  33.27             863  32.566038         2464  33.523810
# Marital
#                Counts      %  | YES:  Counts          %  |NO: Counts          %
# Divorced         2092  20.92             553  20.867925         1539  20.938776
# Widowed          2027  20.27             556  20.981132         1471  20.013605
# Separated        2014  20.14             560  21.132075         1454  19.782313
# Never Married    1956  19.56             488  18.415094         1468  19.972789
# Married          1911  19.11             493  18.603774         1418  19.292517
# Gender
#            Counts      %  | YES:  Counts          %  |NO: Counts          %
# Female       5025  50.25            1272  48.000000         3753  51.061224
# Male         4744  47.44            1319  49.773585         3425  46.598639
# Nonbinary     231   2.31              59   2.226415          172   2.340136
# Techie
#      Counts      %  | YES:  Counts          %  |NO: Counts          %
# No     8321  83.21            2095  79.056604         6226  84.707483
# Yes    1679  16.79             555  20.943396         1124  15.292517
# InternetService
#              Counts      %  | YES:  Counts          %  |NO: Counts          %
# Fiber Optic    4408  44.08            1040  39.245283         3368  45.823129
# DSL            3463  34.63            1114  42.037736         2349  31.959184
# None           2129  21.29             496  18.716981         1633  22.217687
# Multiple
#      Counts      %  | YES:  Counts          %  |NO: Counts          %
# No     5392  53.92            1139  42.981132         4253  57.863946
# Yes    4608  46.08            1511  57.018868         3097  42.136054
# OnlineBackup
#      Counts      %  | YES:  Counts          %  |NO: Counts         %
# No     5494  54.94            1345  50.754717         4149  56.44898
# Yes    4506  45.06            1305  49.245283         3201  43.55102
# DeviceProtection
#      Counts      %  | YES:  Counts          %  |NO: Counts          %
# No     5614  56.14            1364  51.471698         4250  57.823129
# Yes    4386  43.86            1286  48.528302         3100  42.176871
# StreamingTV
#      Counts      %  | YES:  Counts         %  |NO: Counts          %
# No     5071  50.71             836  31.54717         4235  57.619048
# Yes    4929  49.29            1814  68.45283         3115  42.380952
# StreamingMovies
#      Counts     %  | YES:  Counts          %  |NO: Counts          %
# No     5110  51.1             716  27.018868         4394  59.782313
# Yes    4890  48.9            1934  72.981132         2956  40.217687
# Port_modem
#      Counts      %  | YES:  Counts          %  |NO: Counts          %
# No     5166  51.66            1351  50.981132         3815  51.904762
# Yes    4834  48.34            1299  49.018868         3535  48.095238
# Tablet
#      Counts      %  | YES:  Counts          %  |NO: Counts          %
# No     7009  70.09            1863  70.301887         5146  70.013605
# Yes    2991  29.91             787  29.698113         2204  29.986395
# OnlineSecurity
#      Counts      %  | YES:  Counts          %  |NO: Counts         %
# No     6424  64.24            1731  65.320755         4693  63.85034
# Yes    3576  35.76             919  34.679245         2657  36.14966
# TechSupport
#      Counts     %  | YES:  Counts          %  |NO: Counts          %
# No     6250  62.5            1616  60.981132         4634  63.047619
# Yes    3750  37.5            1034  39.018868         2716  36.952381
# Contract
#                 Counts      %  ...  |NO: Counts          %
# Month-to-month    5456  54.56  ...         3422  46.557823
# Two Year          2442  24.42  ...         2133  29.020408
# One year          2102  21.02  ...         1795  24.421769
#
# [3 rows x 6 columns]
# PaperlessBilling
#      Counts      %  | YES:  Counts          %  |NO: Counts          %
# Yes    5882  58.82            1574  59.396226         4308  58.612245
# No     4118  41.18            1076  40.603774         3042  41.387755
# PaymentMethod
#                           Counts      %  ...  |NO: Counts          %
# Electronic Check            3398  33.98  ...         2435  33.129252
# Mailed Check                2290  22.90  ...         1701  23.142857
# Bank Transfer(automatic)    2229  22.29  ...         1671  22.734694
# Credit Card (automatic)     2083  20.83  ...         1543  20.993197
#
# [4 rows x 6 columns]
# TimeZone
#                                 Counts      %  ...  |NO: Counts          %
# America/New_York                  4072  40.72  ...         2999  40.802721
# America/Chicago                   3672  36.72  ...         2703  36.775510
# America/Los_Angeles                887   8.87  ...          644   8.761905
# America/Denver                     552   5.52  ...          408   5.551020
# America/Detroit                    265   2.65  ...          192   2.612245
# America/Indiana/Indianapolis       186   1.86  ...          137   1.863946
# America/Phoenix                    104   1.04  ...           76   1.034014
# America/Boise                       57   0.57  ...           44   0.598639
# America/Anchorage                   55   0.55  ...           37   0.503401
# America/Puerto_Rico                 40   0.40  ...           30   0.408163
# Pacific/Honolulu                    35   0.35  ...           29   0.394558
# America/Menominee                   16   0.16  ...            9   0.122449
# America/Nome                        12   0.12  ...            9   0.122449
# America/Kentucky/Louisville         10   0.10  ...            7   0.095238
# America/Sitka                        8   0.08  ...            6   0.081633
# America/Indiana/Vincennes            6   0.06  ...            3   0.040816
# America/Indiana/Tell_City            6   0.06  ...            5   0.068027
# America/Toronto                      5   0.05  ...            2   0.027211
# America/Indiana/Petersburg           4   0.04  ...            2   0.027211
# America/Juneau                       2   0.02  ...            2   0.027211
# America/North_Dakota/New_Salem       2   0.02  ...            2   0.027211
# America/Indiana/Winamac              1   0.01  ...            1   0.013605
# America/Indiana/Marengo              1   0.01  ...            1   0.013605
# America/Ojinaga                      1   0.01  ...            1   0.013605
# America/Indiana/Knox                 1   0.01  ...            1   0.013605
#
# [25 rows x 6 columns]
# Item1
#    Counts      %  | YES:  Counts          %  |NO: Counts          %
# 3    3448  34.48             886  33.433962         2562  34.857143
# 4    3358  33.58             885  33.396226         2473  33.646259
# 2    1393  13.93             391  14.754717         1002  13.632653
# 5    1359  13.59             365  13.773585          994  13.523810
# 1     224   2.24              66   2.490566          158   2.149660
# 6     199   1.99              53   2.000000          146   1.986395
# 7      19   0.19               4   0.150943           15   0.204082
# Item2
#    Counts      %  | YES:  Counts          %  |NO: Counts          %
# 1     217   2.17              57   2.150943          160   2.176871
# 2    1360  13.60             387  14.603774          973  13.238095
# 3    3415  34.15             896  33.811321         2519  34.272109
# 4    3412  34.12             905  34.150943         2507  34.108844
# 5    1368  13.68             343  12.943396         1025  13.945578
# 6     215   2.15              60   2.264151          155   2.108844
# 7      13   0.13               2   0.075472           11   0.149660
# Item3
#    Counts      %  | YES:  Counts          %  |NO: Counts          %
# 1     202   2.02            56.0   2.113208          146   1.986395
# 2    1424  14.24           407.0  15.358491         1017  13.836735
# 3    3435  34.35           895.0  33.773585         2540  34.557823
# 4    3410  34.10           883.0  33.320755         2527  34.380952
# 5    1313  13.13           353.0  13.320755          960  13.061224
# 6     203   2.03            54.0   2.037736          149   2.027211
# 7      12   0.12             2.0   0.075472           10   0.136054
# 8       1   0.01             NaN        NaN            1   0.013605
# Item4
#    Counts      %  | YES:  Counts          %  |NO: Counts          %
# 1     221   2.21              59   2.226415          162   2.204082
# 2    1350  13.50             360  13.584906          990  13.469388
# 3    3430  34.30             906  34.188679         2524  34.340136
# 4    3452  34.52             929  35.056604         2523  34.326531
# 5    1335  13.35             337  12.716981          998  13.578231
# 6     203   2.03              58   2.188679          145   1.972789
# 7       9   0.09               1   0.037736            8   0.108844
# Item5
#    Counts      %  | YES:  Counts          %  |NO: Counts          %
# 1     206   2.06              62   2.339623          144   1.959184
# 2    1378  13.78             369  13.924528         1009  13.727891
# 3    3462  34.62             941  35.509434         2521  34.299320
# 4    3417  34.17             876  33.056604         2541  34.571429
# 5    1321  13.21             347  13.094340          974  13.251701
# 6     204   2.04              54   2.037736          150   2.040816
# 7      12   0.12               1   0.037736           11   0.149660
# Item6
#    Counts      %  | YES:  Counts          %  |NO: Counts          %
# 1     190   1.90            54.0   2.037736          136   1.850340
# 2    1427  14.27           386.0  14.566038         1041  14.163265
# 3    3445  34.45           888.0  33.509434         2557  34.789116
# 4    3333  33.33           897.0  33.849057         2436  33.142857
# 5    1382  13.82           358.0  13.509434         1024  13.931973
# 6     210   2.10            64.0   2.415094          146   1.986395
# 7      12   0.12             3.0   0.113208            9   0.122449
# 8       1   0.01             NaN        NaN            1   0.013605
# Item7
#    Counts      %  | YES:  Counts          %  |NO: Counts          %
# 1     219   2.19              58   2.188679          161   2.190476
# 2    1309  13.09             363  13.698113          946  12.870748
# 3    3446  34.46             930  35.094340         2516  34.231293
# 4    3456  34.56             871  32.867925         2585  35.170068
# 5    1335  13.35             368  13.886792          967  13.156463
# 6     224   2.24              58   2.188679          166   2.258503
# 7      11   0.11               2   0.075472            9   0.122449
# Item8
#    Counts      %  | YES:  Counts          %  |NO: Counts          %
# 1     206   2.06            56.0   2.113208          150   2.040816
# 2    1378  13.78           366.0  13.811321         1012  13.768707
# 3    3461  34.61           904.0  34.113208         2557  34.789116
# 4    3400  34.00           899.0  33.924528         2501  34.027211
# 5    1335  13.35           361.0  13.622642          974  13.251701
# 6     205   2.05            60.0   2.264151          145   1.972789
# 7      14   0.14             4.0   0.150943           10   0.136054
# 8       1   0.01             NaN        NaN            1   0.013605
# Job
#                                       Counts     %  ...  |NO: Counts         %
# Occupational psychologist                 30  0.30  ...           21  0.285714
# Hospital pharmacist                       28  0.28  ...           18  0.244898
# Horticultural therapist                   28  0.28  ...           19  0.258503
# Comptroller                               28  0.28  ...           22  0.299320
# Psychotherapist, child                    27  0.27  ...           19  0.258503
# ...                                      ...   ...  ...          ...       ...
# Control and instrumentation engineer       6  0.06  ...            5  0.068027
# Toxicologist                               6  0.06  ...            5  0.068027
# Travel agency manager                      6  0.06  ...            1  0.013605
# Arboriculturist                            6  0.06  ...            2  0.027211
# Accountant, chartered certified            6  0.06  ...            4  0.054422
#
# [639 rows x 6 columns]

# %% [markdown]
# # Insigts
