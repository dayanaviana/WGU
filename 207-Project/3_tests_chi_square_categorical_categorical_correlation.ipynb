# %% [markdown]
# <a href="https://colab.research.google.com/github/dayanaviana/WGU/blob/main/207-Project/3_tests_chi_square_categorical_categorical_correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pearson’s Chi-Squared test
#
# H0: NO statistic significant difference between groups
#
# H1: Correlation exists
#
#
#     If Statistic >= Critical Value: significant result, reject null hypothesis (H0), dependent.
#     If Statistic < Critical Value: not significant result, fail to reject null hypothesis (H0), independent.
#
#     If p-value <= alpha: significant result, reject null hypothesis (H0), dependent.
#     If p-value > alpha: not significant result, fail to reject null hypothesis (H0), independent.

# %% [markdown]
# ## Load dataset

# %%
#churn_clean_altered.csv
docId= "1-WjyGAwXhgkEMSGk1PHKMjIASkVgn-YO"
googleDriveFile = "https://docs.google.com/uc?id="+docId+"&export=download"

# import into data frame
import pandas as pd
df = pd.read_csv(googleDriveFile, index_col=0)

# %% [markdown]
# # Create subset with categorical data only
# ## categorical_columns & categorical_df

# %%
categorical_columns = [
                  "Churn",
                 "State",
                 "County",
                 "Area",
                 "Marital",
                 "Gender",
                 "Techie",
                 "InternetService",
                 "Multiple",
                 "OnlineBackup",
                 "DeviceProtection",
                 "StreamingTV",
                 "StreamingMovies",
                 "Port_modem",
                 "Tablet",
                 "OnlineSecurity",
                 "TechSupport",
                 "Contract",
                 "PaperlessBilling",
                 "PaymentMethod",
                 "TimeZone",
                 "Item1",
                 "Item2",
                 "Item3",
                 "Item4",
                 "Item5",
                 "Item6",
                 "Item7",
                 "Item8"
                 ]
#Select columns
categorical_df = df.loc[:, categorical_columns]

# %% [markdown]
# # Cross tabulation and Chi-square Tests

# %%
rows = len(categorical_df)
columns = len(categorical_df.columns)
degress_of_freedom_math = (rows - 1) * (columns - 1)

# %%
# Checking if feature order matters
crossTab = pd.crosstab(index=categorical_df['Churn'], columns=categorical_df['Techie'])
crossTab1 = pd.crosstab(index=categorical_df['Techie'], columns=categorical_df['Churn'])
print(stats.chi2_contingency(crossTab))
print(stats.chi2_contingency(crossTab1))
# Out:
# (44.11479393861451, 3.096716355509661e-11, 1, array([[6115.935, 1234.065],
#        [2205.065,  444.935]]))
# (44.11479393861451, 3.096716355509661e-11, 1, array([[6115.935, 2205.065],
#        [1234.065,  444.935]]))

# %%
from scipy import stats

myDictionaty = dict()
# Compare every feature with each other
for index, column_name in enumerate(categorical_columns):
  iterator = index + 1
  while iterator < len(categorical_columns):
    print("\n")
    sub_column_name = categorical_columns[iterator]
    features = column_name + " & " + sub_column_name
    print(features)
          
    # Cross tabulation
    crossTab = pd.crosstab(index=categorical_df[column_name], columns=categorical_df[sub_column_name])

    #Performing Chi-square test
    # H0: NO statistic significant difference between groups
    # H1: Correlation exists
    h1 = False

    print('Chi-square')
    statistic, pValue, dof, expected = stats.chi2_contingency(crossTab)
    prob = 0.95
    print('Degrees of Freedom:%d, probability:%.2f' % (dof, prob))

    print('interpret test-statistic')
    critical = stats.chi2.ppf(prob, dof)
    # statistic measure distance between observed and expected frequencies
    print('  statistic:%.3f >= critical_value:%.3f ?' % (abs(statistic), critical) )
    if abs(statistic) >= critical:
      print('    Dependent! Reject H0.')
      h1 = True
    else:
      print('    Independent (fail to reject H0)')

    print('interpret p-value')
    alpha = 1.0 - prob
    #P-value is the probability of H0 being true
    print('  p-value:%.3f <= significance:%.3f ? ' % (pValue, alpha))
    if pValue <= alpha: # Accept H1
      print('    Dependent! Reject H0.')
    else:
      print('    Independent (fail to reject H0)')
      h1 = False

    if h1:
      key = features
      myDictionaty[key] = statistic
      print(crossTab)

    iterator=iterator+1

print("\nSUMMARY: \nCorrelation exists on beetween these features")
myDictionaty_sorted = dict(sorted(myDictionaty.items(), key=lambda item: item[1]))
# Print dictionary as json format
import json
print(json.dumps(myDictionaty_sorted, indent=4))
# Out:
# Streaming output truncated to the last 5000 lines.
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Techie    No   Yes
# Churn
# No      6226  1124
# Yes     2095   555
#
#
# Churn & InternetService
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:87.462 >= critical_value:5.991 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# InternetService   DSL  Fiber Optic  None
# Churn
# No               2349         3368  1633
# Yes              1114         1040   496
#
#
# Churn & Multiple
# Chi-square
# Degrees of Freedom:1, probability:0.95
# interpret test-statistic
#   statistic:173.038 >= critical_value:3.841 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Multiple    No   Yes
# Churn
# No        4253  3097
# Yes       1139  1511
#
#
# Churn & OnlineBackup
# Chi-square
# Degrees of Freedom:1, probability:0.95
# interpret test-statistic
#   statistic:25.282 >= critical_value:3.841 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# OnlineBackup    No   Yes
# Churn
# No            4149  3201
# Yes           1345  1305
#
#
# Churn & DeviceProtection
# Chi-square
# Degrees of Freedom:1, probability:0.95
# interpret test-statistic
#   statistic:31.653 >= critical_value:3.841 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# DeviceProtection    No   Yes
# Churn
# No                4250  3100
# Yes               1364  1286
#
#
# Churn & StreamingTV
# Chi-square
# Degrees of Freedom:1, probability:0.95
# interpret test-statistic
#   statistic:528.652 >= critical_value:3.841 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# StreamingTV    No   Yes
# Churn
# No           4235  3115
# Yes           836  1814
#
#
# Churn & StreamingMovies
# Chi-square
# Degrees of Freedom:1, probability:0.95
# interpret test-statistic
#   statistic:835.414 >= critical_value:3.841 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# StreamingMovies    No   Yes
# Churn
# No               4394  2956
# Yes               716  1934
#
#
# Churn & Port_modem
# Chi-square
# Degrees of Freedom:1, probability:0.95
# interpret test-statistic
#   statistic:0.629 >= critical_value:3.841 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.428 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & Tablet
# Chi-square
# Degrees of Freedom:1, probability:0.95
# interpret test-statistic
#   statistic:0.064 >= critical_value:3.841 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.800 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & OnlineSecurity
# Chi-square
# Degrees of Freedom:1, probability:0.95
# interpret test-statistic
#   statistic:1.770 >= critical_value:3.841 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.183 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & TechSupport
# Chi-square
# Degrees of Freedom:1, probability:0.95
# interpret test-statistic
#   statistic:3.461 >= critical_value:3.841 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.063 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & Contract
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:718.592 >= critical_value:5.991 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Contract  Month-to-month  One year  Two Year
# Churn
# No                  3422      1795      2133
# Yes                 2034       307       309
#
#
# Churn & PaperlessBilling
# Chi-square
# Degrees of Freedom:1, probability:0.95
# interpret test-statistic
#   statistic:0.462 >= critical_value:3.841 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.497 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & PaymentMethod
# Chi-square
# Degrees of Freedom:3, probability:0.95
# interpret test-statistic
#   statistic:9.437 >= critical_value:7.815 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.024 <= significance:0.050 ?
#     Dependent! Reject H0.
# PaymentMethod  Bank Transfer(automatic)  ...  Mailed Check
# Churn                                    ...
# No                                 1671  ...          1701
# Yes                                 558  ...           589
#
# [2 rows x 4 columns]
#
#
# Churn & TimeZone
# Chi-square
# Degrees of Freedom:24, probability:0.95
# interpret test-statistic
#   statistic:15.187 >= critical_value:36.415 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.915 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & Item1
# Chi-square
# Degrees of Freedom:6, probability:0.95
# interpret test-statistic
#   statistic:4.332 >= critical_value:12.592 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.632 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & Item2
# Chi-square
# Degrees of Freedom:6, probability:0.95
# interpret test-statistic
#   statistic:5.272 >= critical_value:12.592 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.509 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & Item3
# Chi-square
# Degrees of Freedom:7, probability:0.95
# interpret test-statistic
#   statistic:5.371 >= critical_value:14.067 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.615 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & Item4
# Chi-square
# Degrees of Freedom:6, probability:0.95
# interpret test-statistic
#   statistic:2.961 >= critical_value:12.592 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.814 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & Item5
# Chi-square
# Degrees of Freedom:6, probability:0.95
# interpret test-statistic
#   statistic:5.625 >= critical_value:12.592 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.466 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & Item6
# Chi-square
# Degrees of Freedom:7, probability:0.95
# interpret test-statistic
#   statistic:4.129 >= critical_value:14.067 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.765 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & Item7
# Chi-square
# Degrees of Freedom:6, probability:0.95
# interpret test-statistic
#   statistic:5.638 >= critical_value:12.592 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.465 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Churn & Item8
# Chi-square
# Degrees of Freedom:7, probability:0.95
# interpret test-statistic
#   statistic:1.714 >= critical_value:14.067 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.974 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & County
# Chi-square
# Degrees of Freedom:82569, probability:0.95
# interpret test-statistic
#   statistic:345959.557 >= critical_value:83238.557 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# County  Acadia  Accomack  Ada  Adair  ...  Yukon-Koyukuk  Yuma  Zapata  Zavala
# State                                 ...
# AK           0         0    0      0  ...             10     0       0       0
# AL           0         0    0      0  ...              0     0       0       0
# AR           0         0    0      0  ...              0     0       0       0
# AZ           0         0    0      0  ...              0     4       0       0
# CA           0         0    0      0  ...              0     0       0       0
# CO           0         0    0      0  ...              0     1       0       0
# CT           0         0    0      0  ...              0     0       0       0
# DC           0         0    0      0  ...              0     0       0       0
# DE           0         0    0      0  ...              0     0       0       0
# FL           0         0    0      0  ...              0     0       0       0
# GA           0         0    0      0  ...              0     0       0       0
# HI           0         0    0      0  ...              0     0       0       0
# IA           0         0    0      4  ...              0     0       0       0
# ID           0         0    7      0  ...              0     0       0       0
# IL           0         0    0      0  ...              0     0       0       0
# IN           0         0    0      0  ...              0     0       0       0
# KS           0         0    0      0  ...              0     0       0       0
# KY           0         0    0      1  ...              0     0       0       0
# LA           3         0    0      0  ...              0     0       0       0
# MA           0         0    0      0  ...              0     0       0       0
# MD           0         0    0      0  ...              0     0       0       0
# ME           0         0    0      0  ...              0     0       0       0
# MI           0         0    0      0  ...              0     0       0       0
# MN           0         0    0      0  ...              0     0       0       0
# MO           0         0    0      6  ...              0     0       0       0
# MS           0         0    0      0  ...              0     0       0       0
# MT           0         0    0      0  ...              0     0       0       0
# NC           0         0    0      0  ...              0     0       0       0
# ND           0         0    0      0  ...              0     0       0       0
# NE           0         0    0      0  ...              0     0       0       0
# NH           0         0    0      0  ...              0     0       0       0
# NJ           0         0    0      0  ...              0     0       0       0
# NM           0         0    0      0  ...              0     0       0       0
# NV           0         0    0      0  ...              0     0       0       0
# NY           0         0    0      0  ...              0     0       0       0
# OH           0         0    0      0  ...              0     0       0       0
# OK           0         0    0      2  ...              0     0       0       0
# OR           0         0    0      0  ...              0     0       0       0
# PA           0         0    0      0  ...              0     0       0       0
# PR           0         0    0      0  ...              0     0       0       0
# RI           0         0    0      0  ...              0     0       0       0
# SC           0         0    0      0  ...              0     0       0       0
# SD           0         0    0      0  ...              0     0       0       0
# TN           0         0    0      0  ...              0     0       0       0
# TX           0         0    0      0  ...              0     0       1       1
# UT           0         0    0      0  ...              0     0       0       0
# VA           0         6    0      0  ...              0     0       0       0
# VT           0         0    0      0  ...              0     0       0       0
# WA           0         0    0      0  ...              0     0       0       0
# WI           0         0    0      0  ...              0     0       0       0
# WV           0         0    0      0  ...              0     0       0       0
# WY           0         0    0      0  ...              0     0       0       0
#
# [52 rows x 1620 columns]
#
#
# State & Area
# Chi-square
# Degrees of Freedom:102, probability:0.95
# interpret test-statistic
#   statistic:103.776 >= critical_value:126.574 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.432 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Marital
# Chi-square
# Degrees of Freedom:204, probability:0.95
# interpret test-statistic
#   statistic:181.814 >= critical_value:238.322 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.866 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Gender
# Chi-square
# Degrees of Freedom:102, probability:0.95
# interpret test-statistic
#   statistic:77.543 >= critical_value:126.574 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.966 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Techie
# Chi-square
# Degrees of Freedom:51, probability:0.95
# interpret test-statistic
#   statistic:54.229 >= critical_value:68.669 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.352 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & InternetService
# Chi-square
# Degrees of Freedom:102, probability:0.95
# interpret test-statistic
#   statistic:121.558 >= critical_value:126.574 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.091 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Multiple
# Chi-square
# Degrees of Freedom:51, probability:0.95
# interpret test-statistic
#   statistic:35.666 >= critical_value:68.669 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.949 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & OnlineBackup
# Chi-square
# Degrees of Freedom:51, probability:0.95
# interpret test-statistic
#   statistic:41.938 >= critical_value:68.669 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.813 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & DeviceProtection
# Chi-square
# Degrees of Freedom:51, probability:0.95
# interpret test-statistic
#   statistic:46.351 >= critical_value:68.669 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.659 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & StreamingTV
# Chi-square
# Degrees of Freedom:51, probability:0.95
# interpret test-statistic
#   statistic:50.260 >= critical_value:68.669 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.503 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & StreamingMovies
# Chi-square
# Degrees of Freedom:51, probability:0.95
# interpret test-statistic
#   statistic:37.704 >= critical_value:68.669 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.917 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Port_modem
# Chi-square
# Degrees of Freedom:51, probability:0.95
# interpret test-statistic
#   statistic:45.750 >= critical_value:68.669 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.682 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Tablet
# Chi-square
# Degrees of Freedom:51, probability:0.95
# interpret test-statistic
#   statistic:47.415 >= critical_value:68.669 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.617 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & OnlineSecurity
# Chi-square
# Degrees of Freedom:51, probability:0.95
# interpret test-statistic
#   statistic:50.856 >= critical_value:68.669 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.479 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & TechSupport
# Chi-square
# Degrees of Freedom:51, probability:0.95
# interpret test-statistic
#   statistic:54.122 >= critical_value:68.669 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.356 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Contract
# Chi-square
# Degrees of Freedom:102, probability:0.95
# interpret test-statistic
#   statistic:111.351 >= critical_value:126.574 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.248 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & PaperlessBilling
# Chi-square
# Degrees of Freedom:51, probability:0.95
# interpret test-statistic
#   statistic:35.096 >= critical_value:68.669 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.956 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & PaymentMethod
# Chi-square
# Degrees of Freedom:153, probability:0.95
# interpret test-statistic
#   statistic:153.164 >= critical_value:182.865 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.481 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & TimeZone
# Chi-square
# Degrees of Freedom:1224, probability:0.95
# interpret test-statistic
#   statistic:92284.194 >= critical_value:1306.504 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# TimeZone  America/Anchorage  America/Boise  ...  America/Toronto  Pacific/Honolulu
# State                                       ...
# AK                       55              0  ...                0                 0
# AL                        0              0  ...                0                 0
# AR                        0              0  ...                0                 0
# AZ                        0              0  ...                0                 0
# CA                        0              0  ...                0                 0
# CO                        0              0  ...                0                 0
# CT                        0              0  ...                0                 0
# DC                        0              0  ...                0                 0
# DE                        0              0  ...                0                 0
# FL                        0              0  ...                0                 0
# GA                        0              0  ...                0                 0
# HI                        0              0  ...                0                35
# IA                        0              0  ...                0                 0
# ID                        0             54  ...                0                 0
# IL                        0              0  ...                0                 0
# IN                        0              0  ...                0                 0
# KS                        0              0  ...                0                 0
# KY                        0              0  ...                0                 0
# LA                        0              0  ...                0                 0
# MA                        0              0  ...                0                 0
# MD                        0              0  ...                0                 0
# ME                        0              0  ...                0                 0
# MI                        0              0  ...                1                 0
# MN                        0              0  ...                0                 0
# MO                        0              0  ...                0                 0
# MS                        0              0  ...                0                 0
# MT                        0              0  ...                0                 0
# NC                        0              0  ...                0                 0
# ND                        0              0  ...                0                 0
# NE                        0              0  ...                0                 0
# NH                        0              0  ...                0                 0
# NJ                        0              0  ...                0                 0
# NM                        0              0  ...                0                 0
# NV                        0              0  ...                0                 0
# NY                        0              0  ...                4                 0
# OH                        0              0  ...                0                 0
# OK                        0              0  ...                0                 0
# OR                        0              3  ...                0                 0
# PA                        0              0  ...                0                 0
# PR                        0              0  ...                0                 0
# RI                        0              0  ...                0                 0
# SC                        0              0  ...                0                 0
# SD                        0              0  ...                0                 0
# TN                        0              0  ...                0                 0
# TX                        0              0  ...                0                 0
# UT                        0              0  ...                0                 0
# VA                        0              0  ...                0                 0
# VT                        0              0  ...                0                 0
# WA                        0              0  ...                0                 0
# WI                        0              0  ...                0                 0
# WV                        0              0  ...                0                 0
# WY                        0              0  ...                0                 0
#
# [52 rows x 25 columns]
#
#
# State & Item1
# Chi-square
# Degrees of Freedom:306, probability:0.95
# interpret test-statistic
#   statistic:313.941 >= critical_value:347.796 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.365 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Item2
# Chi-square
# Degrees of Freedom:306, probability:0.95
# interpret test-statistic
#   statistic:317.063 >= critical_value:347.796 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.320 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Item3
# Chi-square
# Degrees of Freedom:357, probability:0.95
# interpret test-statistic
#   statistic:431.859 >= critical_value:402.059 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.004 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item3   1   2    3    4   5   6  7  8
# State
# AK      1  11   24   29  11   1  0  0
# AL      1  26   62   65  20   6  1  0
# AR      1  20   62   61  28   4  0  0
# AZ      3  15   39   41  13   1  0  0
# CA      7  82  183  176  72   6  0  0
# CO      4  29   53   46  23   0  0  0
# CT      1  11   17   28  11   3  0  0
# DC      0   2    4    7   1   0  0  0
# DE      3   5    5    5   3   0  0  0
# FL      5  43  124  106  43   3  0  0
# GA      6  35   87   77  27   6  0  0
# HI      1   2   14   13   3   2  0  0
# IA      8  26  110   93  39   3  0  0
# ID      2  12   32   25  10   0  0  0
# IL      5  57  147  143  50  11  0  0
# IN      8  36   82   75  31   7  2  0
# KS      2  31   55   71  33   2  1  0
# KY      6  33   74   87  34   4  0  0
# LA      0  21   47   49  21   3  0  0
# MA      2  26   59   55  26   4  0  0
# MD      3  19   37   45  15   4  0  0
# ME      1  18   34   38  18   3  0  0
# MI      5  52   92   90  34   6  0  0
# MN      7  34   90   92  32   9  0  0
# MO      8  42   97  123  38   2  0  0
# MS      4  25   42   44   8   3  0  0
# MT      2  12   33   28  19   2  0  0
# NC      4  31   92  105  41   7  0  0
# ND      5  15   41   43  14   0  0  0
# NE      2  30   60   62  24   3  0  0
# NH      1  14   31   24  11   3  0  1
# NJ      1  29   66   62  32   0  0  0
# NM      1  24   30   42  15   2  0  0
# NV      0   2   15   24   7   0  0  0
# NY     14  71  180  205  76  12  0  0
# OH      6  56  121  123  47   5  1  0
# OK      3  30   75   62  29   4  0  0
# OR      4  13   44   38  12   3  0  0
# PA     15  75  192  168  79  19  2  0
# PR      1   1   17   16   4   1  0  0
# RI      0   1    5    6   7   0  0  0
# SC      3  14   48   41  13   4  1  0
# SD      3   8   34   40  13   3  0  0
# TN      3  18   61   65  32   6  0  0
# TX     11  95  212  206  67  12  0  0
# UT      2  10   27   19   8   0  0  0
# VA     10  39   89   90  48   8  1  0
# VT      1  12   33   26  10   1  1  0
# WA      4  22   74   56  14   4  1  0
# WI      6  40   79   76  22   5  0  0
# WV      5  42   92   84  21   3  0  0
# WY      1   7   12   15   4   3  1  0
#
#
# State & Item4
# Chi-square
# Degrees of Freedom:306, probability:0.95
# interpret test-statistic
#   statistic:281.017 >= critical_value:347.796 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.844 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Item5
# Chi-square
# Degrees of Freedom:306, probability:0.95
# interpret test-statistic
#   statistic:323.203 >= critical_value:347.796 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.239 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Item6
# Chi-square
# Degrees of Freedom:357, probability:0.95
# interpret test-statistic
#   statistic:339.490 >= critical_value:402.059 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.739 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Item7
# Chi-square
# Degrees of Freedom:306, probability:0.95
# interpret test-statistic
#   statistic:295.062 >= critical_value:347.796 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.663 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# State & Item8
# Chi-square
# Degrees of Freedom:357, probability:0.95
# interpret test-statistic
#   statistic:394.552 >= critical_value:402.059 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.083 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & Area
# Chi-square
# Degrees of Freedom:3238, probability:0.95
# interpret test-statistic
#   statistic:3234.802 >= critical_value:3371.495 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.513 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & Marital
# Chi-square
# Degrees of Freedom:6476, probability:0.95
# interpret test-statistic
#   statistic:6360.965 >= critical_value:6664.326 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.844 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & Gender
# Chi-square
# Degrees of Freedom:3238, probability:0.95
# interpret test-statistic
#   statistic:3071.836 >= critical_value:3371.495 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.982 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & Techie
# Chi-square
# Degrees of Freedom:1619, probability:0.95
# interpret test-statistic
#   statistic:1567.746 >= critical_value:1713.721 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.816 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & InternetService
# Chi-square
# Degrees of Freedom:3238, probability:0.95
# interpret test-statistic
#   statistic:3303.526 >= critical_value:3371.495 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.207 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & Multiple
# Chi-square
# Degrees of Freedom:1619, probability:0.95
# interpret test-statistic
#   statistic:1653.504 >= critical_value:1713.721 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.270 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & OnlineBackup
# Chi-square
# Degrees of Freedom:1619, probability:0.95
# interpret test-statistic
#   statistic:1689.301 >= critical_value:1713.721 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.109 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & DeviceProtection
# Chi-square
# Degrees of Freedom:1619, probability:0.95
# interpret test-statistic
#   statistic:1592.450 >= critical_value:1713.721 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.676 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & StreamingTV
# Chi-square
# Degrees of Freedom:1619, probability:0.95
# interpret test-statistic
#   statistic:1545.950 >= critical_value:1713.721 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.902 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & StreamingMovies
# Chi-square
# Degrees of Freedom:1619, probability:0.95
# interpret test-statistic
#   statistic:1614.511 >= critical_value:1713.721 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.527 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & Port_modem
# Chi-square
# Degrees of Freedom:1619, probability:0.95
# interpret test-statistic
#   statistic:1604.738 >= critical_value:1713.721 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.595 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & Tablet
# Chi-square
# Degrees of Freedom:1619, probability:0.95
# interpret test-statistic
#   statistic:1603.012 >= critical_value:1713.721 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.606 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & OnlineSecurity
# Chi-square
# Degrees of Freedom:1619, probability:0.95
# interpret test-statistic
#   statistic:1601.101 >= critical_value:1713.721 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.619 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & TechSupport
# Chi-square
# Degrees of Freedom:1619, probability:0.95
# interpret test-statistic
#   statistic:1578.724 >= critical_value:1713.721 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.759 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & Contract
# Chi-square
# Degrees of Freedom:3238, probability:0.95
# interpret test-statistic
#   statistic:3327.469 >= critical_value:3371.495 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.134 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & PaperlessBilling
# Chi-square
# Degrees of Freedom:1619, probability:0.95
# interpret test-statistic
#   statistic:1607.774 >= critical_value:1713.721 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.574 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & PaymentMethod
# Chi-square
# Degrees of Freedom:4857, probability:0.95
# interpret test-statistic
#   statistic:4902.593 >= critical_value:5020.245 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.320 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & TimeZone
# Chi-square
# Degrees of Freedom:38856, probability:0.95
# interpret test-statistic
#   statistic:144992.742 >= critical_value:39315.668 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# TimeZone       America/Anchorage  ...  Pacific/Honolulu
# County                            ...
# Acadia                         0  ...                 0
# Accomack                       0  ...                 0
# Ada                            0  ...                 0
# Adair                          0  ...                 0
# Adams                          0  ...                 0
# ...                          ...  ...               ...
# Yuba                           0  ...                 0
# Yukon-Koyukuk                 10  ...                 0
# Yuma                           0  ...                 0
# Zapata                         0  ...                 0
# Zavala                         0  ...                 0
#
# [1620 rows x 25 columns]
#
#
# County & Item1
# Chi-square
# Degrees of Freedom:9714, probability:0.95
# interpret test-statistic
#   statistic:10135.811 >= critical_value:9944.398 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.001 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item1          1  2  3  4  5  6  7
# County
# Acadia         0  1  1  1  0  0  0
# Accomack       0  1  2  3  0  0  0
# Ada            0  1  1  4  1  0  0
# Adair          1  3  3  3  3  0  0
# Adams          1  6  9  3  2  0  0
# ...           .. .. .. .. .. .. ..
# Yuba           0  2  0  1  2  0  0
# Yukon-Koyukuk  0  3  0  6  1  0  0
# Yuma           0  1  1  2  1  0  0
# Zapata         0  0  1  0  0  0  0
# Zavala         0  0  1  0  0  0  0
#
# [1620 rows x 7 columns]
#
#
# County & Item2
# Chi-square
# Degrees of Freedom:9714, probability:0.95
# interpret test-statistic
#   statistic:9267.825 >= critical_value:9944.398 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.999 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & Item3
# Chi-square
# Degrees of Freedom:11333, probability:0.95
# interpret test-statistic
#   statistic:9715.751 >= critical_value:11581.768 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:1.000 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & Item4
# Chi-square
# Degrees of Freedom:9714, probability:0.95
# interpret test-statistic
#   statistic:10792.973 >= critical_value:9944.398 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item4          1  2  3   4  5  6  7
# County
# Acadia         0  1  1   1  0  0  0
# Accomack       0  0  2   4  0  0  0
# Ada            0  1  3   3  0  0  0
# Adair          0  1  7   5  0  0  0
# Adams          0  1  6  11  3  0  0
# ...           .. .. ..  .. .. .. ..
# Yuba           0  0  3   1  0  1  0
# Yukon-Koyukuk  0  2  3   3  2  0  0
# Yuma           0  1  1   2  1  0  0
# Zapata         0  1  0   0  0  0  0
# Zavala         1  0  0   0  0  0  0
#
# [1620 rows x 7 columns]
#
#
# County & Item5
# Chi-square
# Degrees of Freedom:9714, probability:0.95
# interpret test-statistic
#   statistic:9798.079 >= critical_value:9944.398 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.272 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & Item6
# Chi-square
# Degrees of Freedom:11333, probability:0.95
# interpret test-statistic
#   statistic:9302.631 >= critical_value:11581.768 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:1.000 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# County & Item7
# Chi-square
# Degrees of Freedom:9714, probability:0.95
# interpret test-statistic
#   statistic:11121.260 >= critical_value:9944.398 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item7          1  2  3   4  5  6  7
# County
# Acadia         0  1  1   0  1  0  0
# Accomack       0  0  1   2  3  0  0
# Ada            0  2  2   2  1  0  0
# Adair          0  1  6   3  3  0  0
# Adams          1  3  5  10  1  1  0
# ...           .. .. ..  .. .. .. ..
# Yuba           0  0  1   3  1  0  0
# Yukon-Koyukuk  0  2  4   4  0  0  0
# Yuma           0  1  2   2  0  0  0
# Zapata         0  1  0   0  0  0  0
# Zavala         0  1  0   0  0  0  0
#
# [1620 rows x 7 columns]
#
#
# County & Item8
# Chi-square
# Degrees of Freedom:11333, probability:0.95
# interpret test-statistic
#   statistic:20450.447 >= critical_value:11581.768 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item8          1  2  3  4  5  6  7  8
# County
# Acadia         0  0  0  2  1  0  0  0
# Accomack       0  2  2  1  1  0  0  0
# Ada            0  1  1  3  1  0  1  0
# Adair          0  2  9  0  2  0  0  0
# Adams          2  1  6  9  2  1  0  0
# ...           .. .. .. .. .. .. .. ..
# Yuba           0  2  1  2  0  0  0  0
# Yukon-Koyukuk  1  2  2  5  0  0  0  0
# Yuma           0  1  3  1  0  0  0  0
# Zapata         0  0  1  0  0  0  0  0
# Zavala         0  0  1  0  0  0  0  0
#
# [1620 rows x 8 columns]
#
#
# Area & Marital
# Chi-square
# Degrees of Freedom:8, probability:0.95
# interpret test-statistic
#   statistic:7.312 >= critical_value:15.507 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.503 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Gender
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:1.985 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.738 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Techie
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:0.721 >= critical_value:5.991 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.697 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & InternetService
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:0.348 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.986 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Multiple
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:0.233 >= critical_value:5.991 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.890 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & OnlineBackup
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:3.643 >= critical_value:5.991 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.162 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & DeviceProtection
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:1.628 >= critical_value:5.991 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.443 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & StreamingTV
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:0.724 >= critical_value:5.991 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.696 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & StreamingMovies
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:0.364 >= critical_value:5.991 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.833 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Port_modem
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:0.906 >= critical_value:5.991 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.636 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Tablet
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:1.157 >= critical_value:5.991 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.561 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & OnlineSecurity
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:1.792 >= critical_value:5.991 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.408 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & TechSupport
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:3.235 >= critical_value:5.991 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.198 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Contract
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:1.375 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.848 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & PaperlessBilling
# Chi-square
# Degrees of Freedom:2, probability:0.95
# interpret test-statistic
#   statistic:1.461 >= critical_value:5.991 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.482 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & PaymentMethod
# Chi-square
# Degrees of Freedom:6, probability:0.95
# interpret test-statistic
#   statistic:4.266 >= critical_value:12.592 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.641 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & TimeZone
# Chi-square
# Degrees of Freedom:48, probability:0.95
# interpret test-statistic
#   statistic:42.193 >= critical_value:65.171 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.709 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Item1
# Chi-square
# Degrees of Freedom:12, probability:0.95
# interpret test-statistic
#   statistic:5.436 >= critical_value:21.026 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.942 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Item2
# Chi-square
# Degrees of Freedom:12, probability:0.95
# interpret test-statistic
#   statistic:6.639 >= critical_value:21.026 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.880 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Item3
# Chi-square
# Degrees of Freedom:14, probability:0.95
# interpret test-statistic
#   statistic:17.458 >= critical_value:23.685 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.233 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Item4
# Chi-square
# Degrees of Freedom:12, probability:0.95
# interpret test-statistic
#   statistic:11.520 >= critical_value:21.026 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.485 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Item5
# Chi-square
# Degrees of Freedom:12, probability:0.95
# interpret test-statistic
#   statistic:10.662 >= critical_value:21.026 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.558 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Item6
# Chi-square
# Degrees of Freedom:14, probability:0.95
# interpret test-statistic
#   statistic:9.525 >= critical_value:23.685 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.796 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Item7
# Chi-square
# Degrees of Freedom:12, probability:0.95
# interpret test-statistic
#   statistic:13.225 >= critical_value:21.026 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.353 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Area & Item8
# Chi-square
# Degrees of Freedom:14, probability:0.95
# interpret test-statistic
#   statistic:29.544 >= critical_value:23.685 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.009 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item8      1    2     3     4    5   6   7  8
# Area
# Rural     61  455  1174  1086  478  72   1  0
# Suburban  64  473  1160  1127  441  70  11  0
# Urban     81  450  1127  1187  416  63   2  1
#
#
# Marital & Gender
# Chi-square
# Degrees of Freedom:8, probability:0.95
# interpret test-statistic
#   statistic:4.302 >= critical_value:15.507 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.829 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & Techie
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:8.127 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.087 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & InternetService
# Chi-square
# Degrees of Freedom:8, probability:0.95
# interpret test-statistic
#   statistic:8.700 >= critical_value:15.507 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.368 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & Multiple
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:2.988 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.560 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & OnlineBackup
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:2.503 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.644 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & DeviceProtection
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:3.926 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.416 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & StreamingTV
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:1.743 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.783 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & StreamingMovies
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:3.460 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.484 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & Port_modem
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:0.862 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.930 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & Tablet
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:5.650 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.227 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & OnlineSecurity
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:4.511 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.341 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & TechSupport
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:2.045 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.727 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & Contract
# Chi-square
# Degrees of Freedom:8, probability:0.95
# interpret test-statistic
#   statistic:5.123 >= critical_value:15.507 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.744 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & PaperlessBilling
# Chi-square
# Degrees of Freedom:4, probability:0.95
# interpret test-statistic
#   statistic:7.253 >= critical_value:9.488 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.123 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & PaymentMethod
# Chi-square
# Degrees of Freedom:12, probability:0.95
# interpret test-statistic
#   statistic:10.647 >= critical_value:21.026 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.559 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & TimeZone
# Chi-square
# Degrees of Freedom:96, probability:0.95
# interpret test-statistic
#   statistic:81.263 >= critical_value:119.871 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.859 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & Item1
# Chi-square
# Degrees of Freedom:24, probability:0.95
# interpret test-statistic
#   statistic:19.615 >= critical_value:36.415 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.718 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & Item2
# Chi-square
# Degrees of Freedom:24, probability:0.95
# interpret test-statistic
#   statistic:25.795 >= critical_value:36.415 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.364 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & Item3
# Chi-square
# Degrees of Freedom:28, probability:0.95
# interpret test-statistic
#   statistic:38.540 >= critical_value:41.337 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.089 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & Item4
# Chi-square
# Degrees of Freedom:24, probability:0.95
# interpret test-statistic
#   statistic:29.309 >= critical_value:36.415 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.209 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & Item5
# Chi-square
# Degrees of Freedom:24, probability:0.95
# interpret test-statistic
#   statistic:26.655 >= critical_value:36.415 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.321 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Marital & Item6
# Chi-square
# ...
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.215 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Item1 & Item6
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:2012.870 >= critical_value:58.124 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item6   1    2     3     4    5   6  7  8
# Item1
# 1      18   77    97    29    3   0  0  0
# 2      83  393   575   285   56   1  0  0
# 3      62  630  1342  1086  299  29  0  0
# 4      27  280  1119  1292  572  67  1  0
# 5       0   44   283   567  374  86  4  1
# 6       0    3    28    65   73  23  7  0
# 7       0    0     1     9    5   4  0  0
#
#
# Item1 & Item7
# Chi-square
# Degrees of Freedom:36, probability:0.95
# interpret test-statistic
#   statistic:1284.541 >= critical_value:50.998 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item7   1    2     3     4    5   6  7
# Item1
# 1      22   79    85    30    8   0  0
# 2      73  326   562   364   59   9  0
# 3      88  516  1360  1133  314  36  1
# 4      34  331  1078  1283  547  83  2
# 5       2   51   319   568  338  76  5
# 6       0    6    37    71   64  18  3
# 7       0    0     5     7    5   2  0
#
#
# Item1 & Item8
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:1001.302 >= critical_value:58.124 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item8   1    2     3     4    5   6   7  8
# Item1
# 1      18   60    89    47    8   2   0  0
# 2      57  319   607   330   75   5   0  0
# 3      84  550  1296  1123  356  39   0  0
# 4      41  373  1065  1267  526  85   1  0
# 5       6   73   368   538  303  61  10  0
# 6       0    3    34    90   58  10   3  1
# 7       0    0     2     5    9   3   0  0
#
#
# Item2 & Item3
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:4515.848 >= critical_value:58.124 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item3   1    2     3     4    5   6  7  8
# Item2
# 1      37  102    66    12    0   0  0  0
# 2      92  454   571   225   17   1  0  0
# 3      62  608  1502  1027  205  11  0  0
# 4      11  237  1063  1479  561  61  0  0
# 5       0   22   227   598  434  80  7  0
# 6       0    1     6    66   93  46  3  0
# 7       0    0     0     3    3   4  2  1
#
#
# Item2 & Item4
# Chi-square
# Degrees of Freedom:36, probability:0.95
# interpret test-statistic
#   statistic:19.891 >= critical_value:50.998 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.986 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Item2 & Item5
# Chi-square
# Degrees of Freedom:36, probability:0.95
# interpret test-statistic
#   statistic:31.098 >= critical_value:50.998 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.701 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Item2 & Item6
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:1562.830 >= critical_value:58.124 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item6   1    2     3     4    5   6  7  8
# Item2
# 1      21   74    85    33    4   0  0  0
# 2      72  362   562   287   76   1  0  0
# 3      71  602  1348  1048  313  33  0  0
# 4      24  317  1103  1313  569  81  4  1
# 5       2   71   315   571  339  65  5  0
# 6       0    1    31    75   78  28  2  0
# 7       0    0     1     6    3   2  1  0
#
#
# Item2 & Item7
# Chi-square
# Degrees of Freedom:36, probability:0.95
# interpret test-statistic
#   statistic:1015.841 >= critical_value:50.998 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item7   1    2     3     4    5   6  7
# Item2
# 1      25   62    83    39    8   0  0
# 2      71  314   533   370   64   8  0
# 3      91  515  1305  1111  353  39  1
# 4      29  337  1123  1302  523  94  4
# 5       3   73   353   543  326  67  3
# 6       0    8    46    87   56  15  3
# 7       0    0     3     4    5   1  0
#
#
# Item2 & Item8
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:731.710 >= critical_value:58.124 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item8   1    2     3     4    5   6  7  8
# Item2
# 1      16   50    90    49   12   0  0  0
# 2      66  299   563   340   82  10  0  0
# 3      66  558  1253  1135  360  43  0  0
# 4      44  366  1133  1249  526  88  6  0
# 5      14  101   375   540  278  54  5  1
# 6       0    4    43    83   72  10  3  0
# 7       0    0     4     4    5   0  0  0
#
#
# Item3 & Item4
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:34.251 >= critical_value:58.124 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.797 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Item3 & Item5
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:36.922 >= critical_value:58.124 ?
#     Independent (fail to reject H0)
# interpret p-value
#   p-value:0.693 <= significance:0.050 ?
#     Independent (fail to reject H0)
#
#
# Item3 & Item6
# Chi-square
# Degrees of Freedom:49, probability:0.95
# interpret test-statistic
#   statistic:1458.419 >= critical_value:66.339 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item6   1    2     3     4    5   6  7  8
# Item3
# 1      20   58    84    34    6   0  0  0
# 2      72  343   572   358   70   9  0  0
# 3      60  593  1318  1079  346  37  1  1
# 4      37  352  1098  1280  563  75  5  0
# 5       1   77   335   508  326  66  0  0
# 6       0    4    38    67   67  23  4  0
# 7       0    0     0     6    4   0  2  0
# 8       0    0     0     1    0   0  0  0
#
#
# Item3 & Item7
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:804.992 >= critical_value:58.124 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item7   1    2     3     4    5   6  7
# Item3
# 1      17   60    75    43    7   0  0
# 2      68  282   581   396   86  11  0
# 3      83  551  1276  1119  354  49  3
# 4      43  322  1109  1293  546  94  3
# 5       8   89   360   529  279  45  3
# 6       0    5    44    69   60  23  2
# 7       0    0     1     7    2   2  0
# 8       0    0     0     0    1   0  0
#
#
# Item3 & Item8
# Chi-square
# Degrees of Freedom:49, probability:0.95
# interpret test-statistic
#   statistic:518.180 >= critical_value:66.339 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item8   1    2     3     4    5   6  7  8
# Item3
# 1      11   44    94    44    8   1  0  0
# 2      53  305   550   401  102  13  0  0
# 3      87  513  1274  1125  381  54  1  0
# 4      45  389  1151  1236  499  83  7  0
# 5      10  111   347   508  281  50  5  1
# 6       0   16    42    80   60   4  1  0
# 7       0    0     2     6    4   0  0  0
# 8       0    0     1     0    0   0  0  0
#
#
# Item4 & Item5
# Chi-square
# Degrees of Freedom:36, probability:0.95
# interpret test-statistic
#   statistic:2314.132 >= critical_value:50.998 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item5   1    2     3     4    5   6  7
# Item4
# 1       0    2    25    74   86  31  3
# 2       1   33   287   539  396  86  8
# 3      22  271  1118  1392  552  74  1
# 4      79  581  1417  1114  249  12  0
# 5      78  398   544   276   38   1  0
# 6      23   88    70    22    0   0  0
# 7       3    5     1     0    0   0  0
#
#
# Item4 & Item6
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:633.970 >= critical_value:58.124 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item6   1    2     3     4    5   6  7  8
# Item4
# 1      15   67    80    46   11   2  0  0
# 2      55  299   531   338  111  16  0  0
# 3      74  555  1268  1101  386  45  1  0
# 4      37  399  1149  1246  537  78  6  0
# 5       8   95   379   524  271  54  3  1
# 6       1   12    35    74   65  14  2  0
# 7       0    0     3     4    1   1  0  0
#
#
# Item4 & Item7
# Chi-square
# Degrees of Freedom:36, probability:0.95
# interpret test-statistic
#   statistic:442.053 >= critical_value:50.998 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item7   1    2     3     4    5   6  7
# Item4
# 1      12   51    91    54   12   1  0
# 2      56  277   505   382  123   7  0
# 3      87  505  1249  1135  388  64  2
# 4      53  357  1149  1278  517  95  3
# 5      10  104   405   525  244  44  3
# 6       1   14    44    78   51  12  3
# 7       0    1     3     4    0   1  0
#
#
# Item4 & Item8
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:277.454 >= critical_value:58.124 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item8   1    2     3     4    5   6  7  8
# Item4
# 1      10   42    95    55   15   4  0  0
# 2      44  244   533   388  129  12  0  0
# 3      71  543  1244  1119  390  62  1  0
# 4      57  410  1138  1247  516  74  9  1
# 5      24  127   395   507  238  41  3  0
# 6       0   11    54    79   47  11  1  0
# 7       0    1     2     5    0   1  0  0
#
#
# Item5 & Item6
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:1054.401 >= critical_value:58.124 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item6   1    2     3     4    5   6  7  8
# Item5
# 1       0    5    32    85   63  19  2  0
# 2       2   78   355   551  318  70  3  1
# 3      34  380  1143  1259  569  73  4  0
# 4      78  546  1318  1081  352  40  2  0
# 5      54  345   521   322   72   6  1  0
# 6      21   69    71    33    8   2  0  0
# 7       1    4     5     2    0   0  0  0
#
#
# Item5 & Item7
# Chi-square
# Degrees of Freedom:36, probability:0.95
# interpret test-statistic
#   statistic:752.124 >= critical_value:50.998 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item7   1    2     3     4    5   6  7
# Item5
# 1       1    4    31    98   54  17  1
# 2       9   86   370   549  299  60  5
# 3      50  346  1138  1310  523  91  4
# 4      83  525  1292  1092  374  51  0
# 5      63  290   530   358   74   5  1
# 6      12   52    83    46   11   0  0
# 7       1    6     2     3    0   0  0
#
#
# Item5 & Item8
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:423.629 >= critical_value:58.124 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item8   1    2     3     4    5   6  7  8
# Item5
# 1       0   14    51    77   49  13  1  1
# 2      13  125   405   506  272  53  4  0
# 3      58  417  1131  1265  516  69  6  0
# 4      84  511  1274  1098  392  55  3  0
# 5      39  255   516   405   92  14  0  0
# 6      12   53    80    44   14   1  0  0
# 7       0    3     4     5    0   0  0  0
#
#
# Item6 & Item7
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:1766.664 >= critical_value:58.124 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item7   1    2     3     4    5   6  7
# Item6
# 1      21   89    61    17    2   0  0
# 2      90  376   563   337   53   8  0
# 3      74  503  1414  1116  308  29  1
# 4      26  282  1081  1319  534  89  2
# 5       7   55   296   591  356  70  7
# 6       1    4    31    71   77  25  1
# 7       0    0     0     5    5   2  0
# 8       0    0     0     0    0   1  0
#
#
# Item6 & Item8
# Chi-square
# Degrees of Freedom:49, probability:0.95
# interpret test-statistic
#   statistic:1123.272 >= critical_value:66.339 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item8   1    2     3     4    5   6  7  8
# Item6
# 1      16   62    82    28    2   0  0  0
# 2      63  321   619   335   83   6  0  0
# 3      88  549  1310  1117  345  36  0  0
# 4      33  360  1072  1262  518  82  6  0
# 5       6   79   339   579  311  63  5  0
# 6       0    7    37    75   71  17  2  1
# 7       0    0     2     4    4   1  1  0
# 8       0    0     0     0    1   0  0  0
#
#
# Item7 & Item8
# Chi-square
# Degrees of Freedom:42, probability:0.95
# interpret test-statistic
#   statistic:744.346 >= critical_value:58.124 ?
#     Dependent! Reject H0.
# interpret p-value
#   p-value:0.000 <= significance:0.050 ?
#     Dependent! Reject H0.
# Item8   1    2     3     4    5   6  7  8
# Item7
# 1      15   65    96    32   10   1  0  0
# 2      49  303   500   351   94  12  0  0
# 3      91  532  1299  1115  363  45  1  0
# 4      45  370  1159  1293  494  90  5  0
# 5       5   98   353   523  305  44  7  0
# 6       1   10    54    82   63  12  1  1
# 7       0    0     0     4    6   1  0  0
#
# SUMMARY:
# Correlation exists on beetween these features
# {
#     "Multiple & Tablet": 3.845081930380937,
#     "StreamingMovies & Tablet": 4.1991556505880805,
#     "Techie & DeviceProtection": 4.441988390142552,
#     "InternetService & TechSupport": 7.537440120131058,
#     "Churn & Gender": 7.880065153719115,
#     "Gender & OnlineBackup": 8.79456858116318,
#     "Churn & PaymentMethod": 9.437373459430551,
#     "Techie & Item8": 15.452037630031873,
#     "TechSupport & Item1": 15.503196063861855,
#     "Churn & OnlineBackup": 25.28155392637337,
#     "Area & Item8": 29.54382434819879,
#     "Churn & DeviceProtection": 31.653203253644485,
#     "Churn & Techie": 44.11479393861451,
#     "Churn & InternetService": 87.46204550568089,
#     "Churn & Multiple": 173.03798837784385,
#     "TimeZone & Item3": 243.93731731925217,
#     "Item4 & Item8": 277.4544693852415,
#     "Item5 & Item8": 423.62879714384644,
#     "State & Item3": 431.8586007826526,
#     "Item4 & Item7": 442.0528471231769,
#     "Item3 & Item8": 518.1803305624537,
#     "Churn & StreamingTV": 528.6518608190515,
#     "Item4 & Item6": 633.9703852534014,
#     "Churn & Contract": 718.5915805949758,
#     "Item2 & Item8": 731.709786629694,
#     "Item7 & Item8": 744.3457532809362,
#     "Item5 & Item7": 752.1240843050649,
#     "Item3 & Item7": 804.9916204578567,
#     "Churn & StreamingMovies": 835.4140130816002,
#     "Item1 & Item8": 1001.3023505931196,
#     "Item2 & Item7": 1015.841130949356,
#     "Item5 & Item6": 1054.4008161284717,
#     "Item6 & Item8": 1123.271706712873,
#     "Item1 & Item7": 1284.5412852534719,
#     "Item3 & Item6": 1458.4186210963944,
#     "Item2 & Item6": 1562.8304603499337,
#     "Item6 & Item7": 1766.664379463188,
#     "Item1 & Item6": 2012.8703231785244,
#     "Item4 & Item5": 2314.1315675105725,
#     "Item2 & Item3": 4515.847842508519,
#     "Item1 & Item3": 5368.283088039158,
#     "Item1 & Item2": 7321.453332258555,
#     "County & Item1": 10135.810588424014,
#     "County & Item4": 10792.973190873017,
#     "County & Item7": 11121.26018487634,
#     "County & Item8": 20450.446966448962,
#     "State & TimeZone": 92284.19396208212,
#     "County & TimeZone": 144992.74201730866,
#     "State & County": 345959.5570305114
# }

# %% [markdown]
# # Insigts
# Relevant correlations
#
#     Multiple & Tablet
#     StreamingMovies & Tablet
#     Techie & DeviceProtection
#     InternetService & TechSupport
#     Gender & OnlineBackup
#
#     Churn & Gender
#     Churn & PaymentMethod
#     Churn & OnlineBackup
#     Churn & DeviceProtection
#     Churn & Techie
#     Churn & InternetService
#     Churn & Multiple
#     Churn & StreamingTV
#     Churn & Contract
#     Churn & StreamingMovies
#
#     TechSupport & Item1: Timely response
#     Techie & Item8:Evidence of active listening
#     TimeZone & Item3:Timely replacements
#     State & Item3
#
#     Item4 & Item8 (Reliability & Evidence of active listening)
#     Item5 & Item8 (Options & Evidence of active listening)
#     Item4 & Item7 (Reliability & Courteous exchange)
#     Item3 & Item8 (Timely replacements & Evidence of active listening)
#     Item4 & Item6 (Reliability & Respectful response)
#     Item2 & Item8 (Timely fixes & Evidence of active listening)
#     Item7 & Item8 (Courteous exchange & Evidence of active listening)
#     Item5 & Item7 (Options & Courteous exchange)
#     Item3 & Item7 (Timely replacements
